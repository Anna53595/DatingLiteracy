# %% [markdown]
# # Categorical Naive Bayes

# %%
import pandas as pd
from utils import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.model_selection import train_test_split

# %%
# Load data
questions = pd.read_csv('data/question_data.csv', sep=';')
questions = questions.set_index('Unnamed: 0')  # set first column (question number) as index
data = pd.read_parquet('data/train.parquet')

# %%
# questions
selected_questions = ['q212813'] + preprocessing.top_k_questions(keyword='descriptive', k=10, questions_df=questions, data=data)
unordered_categories, ordered_categories = preprocessing.get_categories(selected_questions, questions, {'q20930', 'q77', 'q80', 'q79'})
feature_target_df = preprocessing.preprocess(data[selected_questions], unordered_categories, ordered_categories)
display(feature_target_df)
# Out:
# selected questions:  ['Do you like watching foreign movies with subtitles?'
#  'Which type of wine would you prefer to drink outside of a meal, such as for leisure?'
#  'Do you enjoy intense intellectual conversations?'
#  'Have you smoked a cigarette in the last 6 months?'
#  'How frequently do you drink alcohol?' 'Rate your self-confidence:'
#  'How often do you keep your promises?'
#  'How often are you open with your feelings?'
#  "What's your deal with harder drugs (stuff beyond pot)?"
#  'Are you happy with your life?']
#                    q212813                          q416235  \
# index
# 28586             Centrist  Can't answer without a subtitle
# 8701   Liberal / Left-wing                              Yes
# 31844             Centrist                              Yes
# 39046             Centrist  Can't answer without a subtitle
# 21628                Other  Can't answer without a subtitle
# ...                    ...                              ...
# 21184                Other  Can't answer without a subtitle
# 67652                Other  Can't answer without a subtitle
# 60546  Liberal / Left-wing                              Yes
# 1726                 Other  Can't answer without a subtitle
# 26197                Other  Can't answer without a subtitle
#
#                                         q85419 q358084 q501         q77  \
# index
# 28586    White (such as Chardonnay, Riesling).     Yes   No   Sometimes
# 8701           Rosé (such as White Zinfindel).     Yes   No  Very often
# 31844  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 39046          Rosé (such as White Zinfindel).     Yes   No   Sometimes
# 21628  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes      Rarely
# ...                                        ...     ...  ...         ...
# 21184          Rosé (such as White Zinfindel).     Yes   No      Rarely
# 67652  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 60546  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 1726           Rosé (such as White Zinfindel).      No  Yes   Sometimes
# 26197  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes  Very often
#
#                     q20930             q29829   q35660                q80  \
# index
# 28586  Higher than average  Whenever possible  Usually  I never do drugs.
# 8701   Higher than average             Always  Usually  I never do drugs.
# 31844              Average  Whenever possible  Usually  I never do drugs.
# 39046              Average  Whenever possible  Usually  I never do drugs.
# 21628  Higher than average  Whenever possible  Usually  I never do drugs.
# ...                    ...                ...      ...                ...
# 21184              Average             Always   Always  I never do drugs.
# 67652        Below average             Always   Rarely  I never do drugs.
# 60546      Very, very high  Whenever possible   Always  I never do drugs.
# 1726               Average  Whenever possible  Usually  I never do drugs.
# 26197  Higher than average             Always  Usually  I never do drugs.
#
#       q4018
# index
# 28586   Yes
# 8701    Yes
# 31844   Yes
# 39046   Yes
# 21628   Yes
# ...     ...
# 21184   Yes
# 67652   Yes
# 60546   Yes
# 1726    Yes
# 26197   Yes
#
# [26307 rows x 11 columns]

# %%
le_target = LabelEncoder()
y = le_target.fit_transform(feature_target_df.loc[:,'q212813'])
le_target.classes_
print(le_target.inverse_transform([0, 1, 2, 3]))
X = feature_target_df.apply(LabelEncoder().fit_transform, axis=0)
display(y)
display(X)
# Out:
# ['Centrist' 'Conservative / Right-wing' 'Liberal / Left-wing' 'Other']
# array([0, 2, 0, ..., 2, 3, 3])
#        q212813  q416235  q85419  q358084  q501  q77  q20930  q29829  q35660  \
# index
# 28586        0        0       3        1     0    2       2       3       3
# 8701         2        2       2        1     0    3       2       0       3
# 31844        0        2       1        1     0    2       0       3       3
# 39046        0        0       2        1     0    2       0       3       3
# 21628        3        0       1        1     1    1       2       3       3
# ...        ...      ...     ...      ...   ...  ...     ...     ...     ...
# 21184        3        0       2        1     0    1       0       0       0
# 67652        3        0       1        1     0    2       1       0       2
# 60546        2        2       1        1     0    2       3       3       0
# 1726         3        0       2        0     1    2       0       3       3
# 26197        3        0       1        1     1    3       2       0       3
#
#        q80  q4018
# index
# 28586    2      1
# 8701     2      1
# 31844    2      1
# 39046    2      1
# 21628    2      1
# ...    ...    ...
# 21184    2      1
# 67652    2      1
# 60546    2      1
# 1726     2      1
# 26197    2      1
#
# [26307 rows x 11 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print(X_train.shape, X_test.shape)
# Out:
# (17625, 11) (8682, 11)

# %%
clf = CategoricalNB()

clf.fit(X_train, y_train)
pred_train = clf.predict(X_train)
pred_test = clf.predict(X_test)

train_acc = sum(target == prediction for target, prediction in zip(y_train, pred_train))/len(y_train)
test_acc = sum(target == prediction for target, prediction in zip(y_test, pred_test))/len(y_test)
print('train accuracy: ', train_acc)
print('test accuracy: ', test_acc)
# Out:
# (17625, 11)
# [0 1 2 3]
# [-1.68177985 -2.63266645 -0.87925462 -1.11786018]
# [4 3 4 2 2 4 4 4 4 4 2]
# (8682,)
# (8682,)
# (8682,)
# array([2, 0, 1, ..., 3, 2, 1])
# train accuracy:  1.0
# test accuracy:  1.0
