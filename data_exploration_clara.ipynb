# %% [markdown]
# # Data Exploration

# %% [markdown]
# Possible Questions:
# **Can we predict people's political orientation based on how they portray their character traits and habits?**
#
# Data:
# - Cognitive Ability test questions
# - Question_data
# - Parsed_data
#
# Exploration:
# - Keywords
# - Political Questions
# - Descriptive Questions
# - Question Extraction
#
# Source: https://figshare.com/articles/dataset/OKCupid_Datasets/14987388?file=28850916

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(style='darkgrid')

# %%
root_path = 'data/'

# %% [markdown]
# ### Cognitive ability test questions

# %%
# cognitive ability test questions
test_items = pd.read_csv(os.path.join(root_path, 'test_items.csv'))
print(test_items.columns)
print(test_items.shape)

display(test_items.head())
# Out:
# Index(['Unnamed: 0', 'ID', 'text', 'option_1', 'option_2', 'option_3',
#        'option_4', 'option_correct'],
#       dtype='object')
# (28, 8)
#   Unnamed: 0     ID                                               text  \
# 0       q178    178                                   Which is bigger?
# 1       q255    255                STALE is to STEAL as 89475 is to...
# 2      q1201   1201   What is next in this series? 1, 4, 10, 19, 31, _
# 3     q14835  14835  If you turn a left-handed glove inside out, it...
# 4      q8672   8672  In the line 'Wherefore art thou Romeo?' what d...
#
#           option_1          option_2 option_3                 option_4  \
# 0        The earth           The sun      NaN                      NaN
# 1            89457             98547    89754                    89547
# 2               36                48       46  Don't know / don't care
# 3  On my left hand  On my right hand      NaN                      NaN
# 4              Why             Where      How         Who cares / wtf?
#
#    option_correct
# 0               2
# 1               4
# 2               3
# 3               2
# 4               1

# %% [markdown]
# ### Question Data

# %%
question_data = pd.read_csv(os.path.join(root_path, 'question_data.csv'), sep=';')
question_data = question_data.set_index('Unnamed: 0')  # set first column (question number) as index
print('shape', question_data.shape)
print(question_data.columns)
display(question_data.head())
# Out:
# shape (2620, 9)
# Index(['text', 'option_1', 'option_2', 'option_3', 'option_4', 'N', 'Type',
#        'Order', 'Keywords'],
#       dtype='object')
#                                                          text  \
# Unnamed: 0
# q2                                           Breast implants?
# q11         How does the idea of being slapped hard in the...
# q12         Divide your age by 2.  Have you had sex with a...
# q13         Is a girl who's slept with 100 guys a bad person?
# q14         Is a guy who's slept with 100 girls a bad person?
#
#                            option_1                 option_2   option_3  \
# Unnamed: 0
# q2          more cool than pathetic  more pathetic than cool        NaN
# q11                       Horrified                  Aroused  Nostalgic
# q12                             Yes                       No        NaN
# q13                             Yes                       No        NaN
# q14                             Yes                       No        NaN
#
#                option_4      N Type Order                           Keywords
# Unnamed: 0
# q2                  NaN  24839    N   NaN  sex/intimacy; preference; opinion
# q11         Indifferent  28860    N   NaN                       sex/intimacy
# q12                 NaN  22496    O   NaN                       sex/intimacy
# q13                 NaN  32581    O   NaN                       sex/intimacy
# q14                 NaN  31127    O   NaN                       sex/intimacy

# %% [markdown]
# ### Data

# %%
data = pd.read_parquet(os.path.join(root_path, 'parsed_data_public.parquet'))
print('shape', data.shape)
display(data.head())
# Out:
# shape (68371, 2626)
#    Unnamed: 0    q2        q11   q12   q13   q14   q16   q17   q18   q20  ...  \
# 0           1  None  Horrified  None  None  None  None    No  None  None  ...
# 1           2  None       None  None  None  None  None  None  None  None  ...
# 2           3  None       None  None    No    No  None    No  None  None  ...
# 3           4  None       None  None  None  None  None  None  None  None  ...
# 4           5  None       None  None  None  None  None  None  None  None  ...
#
#   q86615 q86699 q363047        CA gender_orientation gender   race gender2  \
# 0   None   None    None  0.763080      Hetero_female  Woman  White   Woman
# 1   None   None    None       NaN        Hetero_male    Man   None     Man
# 2   None   None    None  0.661309      Hetero_female  Woman   None   Woman
# 3   None   None    None       NaN      Hetero_female  Woman  White   Woman
# 4   None   None    None  0.875424    Bisexual_female  Woman   None   Woman
#
#   gender2_num CA_items
# 0         0.0        4
# 1         1.0        0
# 2         0.0        7
# 3         0.0        0
# 4         0.0        3
#
# [5 rows x 2626 columns]

# %% [markdown]
# ## Exploration

# %% [markdown]
# List of keywords

# %%
keys = question_data.Keywords.dropna().unique().tolist()  # set of unique keywords
print('number of unique keywords', len(keys))
print(keys)
# Out:
# number of unique keywords 61
# ['sex/intimacy; preference; opinion', 'sex/intimacy', 'sex/intimacy; BDSM', 'religion/superstition', 'preference', 'descriptive', 'opinion', 'religion/superstition; descriptive', 'politics', 'preference; opinion', 'sex/intimacy; opinion', 'religion/superstition; opinion', 'sex/intimacy; preference; descriptive', 'preference; descriptive', 'sex/intimacy; preference', 'sex/intimacy; descriptive', 'politics; preference', 'politics; opinion', 'cognitive', 'descriptive; cognitive', 'politics; religion/superstition', 'opinion; technology', 'opinion; descriptive', 'politics; preference; opinion; sex/intimacy', 'descriptive; preference', 'politics; preference; descriptive', 'politics; religion/superstition; opinion', 'politics; opinion; sex/intimacy', 'descriptive; technology', 'sex/intimacy; religion/superstition', 'politics; sex/intimacy; religion/superstition ', 'religion/superstition; preference', 'opinion; cognitive', 'politics; preference; opinion', 'preference; descriptive; technology', 'descriptive; preference; opinion', 'politics; descriptive', 'sex/intimacy; preference; BDSM', 'politics; descriptive; preference', 'politics; cognitive', 'preference; descriptive; opinion', 'sex/intimacy; religion/superstition; descriptive', 'politics; religion/superstition; descriptive', 'preference; cognitive', 'preference; descriptive; politics', 'sex/intimacy; religion/superstition; preference', 'sex/intimacy; religion/superstition; opinion', 'politics; sex/intimacy; descriptive', 'preference; technology', 'politics; sex/intimacy; preference', 'politics; sex/intimacy; religion/superstition; opinion', 'politics; opinion; preference', 'politics; opinion; cognitive', 'religion/superstition; descriptive; preference', 'preference; descriptive; cognitive', 'religion/superstition; opinion; cognitive', 'descriptive; opinion', 'politics; religion/superstition; preference', 'sex/intimacy; descriptive; BDSM', 'descriptive; BDSM', 'politics; opinion; technology']

# %%
[key for key in list(keys)[1:] if ";" not in key]
# Out:
# ['sex/intimacy',
#  'religion/superstition',
#  'preference',
#  'descriptive',
#  'opinion',
#  'politics',
#  'cognitive']

# %% [markdown]
# ### Number of answers per question

# %%
# per question count number of times the question is answered
n_answers_per_question = data.notnull().sum(axis=0)[1:] # first column is question name (Unnamed: 0) => [1:]

# append column with number of people who answered the question to question dataframe
question_data = question_data.join(n_answers_per_question.to_frame('n_answers'))

# %% [markdown]
# ### Political Questions

# %%
# find political questions
political_questions = question_data[question_data.Keywords.str.contains('politics', na=False)]
print(f'number of questions involving politcs: {political_questions.shape[0]}')

# sort political questions
sorted_p_questions = political_questions.sort_values(by=['n_answers'], ascending=False)
print(sorted_p_questions['text'].values)
display(sorted_p_questions.head())
political_belief = 'q212813'
# Out:
# number of questions involving politcs: 270
# ['How do you feel about government-subsidized food programs (free lunch, food stamps, etc.)?'
#  'Are you either vegetarian or vegan?' 'Do you enjoy discussing politics?'
#  "Should burning your country's flag be illegal?"
#  'Which best describes your political beliefs?'
#  'Should evolution and creationism be taught side-by-side in school?'
#  'For you personally, is abortion an option in case of an accidental pregnancy?'
#  'Do you believe your country would be more or less safe if every adult owned a gun?'
#  'In a relationship I like to discuss politics with my partner.'
#  'Which is worse: starving children or abused animals?'
#  'The idea of gay and lesbian couples having children is:'
#  'When men show extra courtesy toward women (opening doors, pulling out chairs, etc.), this is:'
#  'Can anything be made the subject of a joke?'
#  'Which is more offensive: book burning or flag burning?'
#  'Are you okay with people who grow marijuana for their own personal use?'
#  'Would the world be a better place if people with low IQs were not allowed to reproduce?'
#  'Is interracial marriage a bad idea?'
#  'Regardless of whether or not you smoke marijuana, do you think it should be legalized for adults?'
#  'How important is voting to you?'
#  'What do you think of laws that make smoking illegal in bars and restaurants?'
#  'Which would you rather lose?'
#  "Do you care about other people's suffering?"
#  'Could you date someone who has strong political opinions that are the exact opposite of yours?'
#  'Which best represents your opinion of same-sex relationships?'
#  'Are some human lives worth more than others?'
#  'Once you take a moral position, can anything be said or done to change your mind?'
#  'How trusting are you where it concerns your government?'
#  'Are politics interesting?' 'Which is more important for a good match?'
#  'Do you believe that there exists a statistical correlation between race and intelligence?'
#  'Should prostitution be legal?' "What's more important to you?"
#  'Do you think the government should limit big chain stores to give small businesses a chance?'
#  'Do you recycle?'
#  'Is a welfare system a good idea? Or does taxing for it just take money away from hard-working people who earned it?'
#  'Do you have a problem with people who wear fur clothing?'
#  'Which would you rather choose: peace on Earth or loads of money?'
#  'Do you believe that art and literature courses are important to students, even if they are majoring in other fields?'
#  'Should wealthier people pay higher taxes?'
#  'Is global warming a serious problem?'
#  'Should sex education be taught in schools?'
#  'The life of one of your fellow citizens is more valuable than the lives of ten foreigners.'
#  'Do you find it disturbing that products are still tested on animals?'
#  'Overall, has capitalism made the world a better place?'
#  'Do you make any special efforts to support small, independent businesses instead of the big chains?'
#  'Do you have a problem with authority?' 'Should speech be...'
#  'Have you ever attended a political demonstration or convention?'
#  'Have you ever felt so strongly about a social issue or cause that you have participated in a public demonstration?'
#  'Communism, in concept:' 'Can people of color be racist?'
#  "What's your opinion of male crossdressers?"
#  'Do you usually vote in presidential (or applicable) elections?'
#  'Does violence ever solve anything?'
#  'Is anything in life more important than your own self-interest?'
#  'Do you listen to conservative talk radio?'
#  'Do you feel that animals are more important than humans?'
#  'Did America really put a man on the moon?'
#  'A difference of opinion over which of the following topics would most likely make you think twice about dating someone?'
#  "Do you think humans have enough respect for the Earth's other species?"
#  'Should the death penalty be abolished?'
#  'Is it wrong to cultivate or manufacture illegal drugs?'
#  'Would you ever consider being a vegetarian or a vegan?'
#  'Is separation of church and state important to you?'
#  'Is it better to live by your own moral standards and allow others to live by theirs, or is it better to press your moral standards upon other people?'
#  'If someone intentionally damaged your property, would you be more likely to call the police, or to fight them?'
#  'Do you think the basic instinct to survive and reproduce fundamentally drives every decision a person makes?'
#  'Have you ever donated your money or your time to a political campaign or political organization?'
#  'Do you think people living in rural areas are more ignorant, on average, than city folks?'
#  'Suppose you have an attractive cousin, and the cousin is also attracted to you. Suppose both you and your cousin are adults. Would you have non-procreative sex with your cousin?'
#  'Do you think that people should be allowed to marry more than one person at a time?'
#  'Do you believe it is important to stay informed about political issues affecting your nation?'
#  'Do you believe that heterosexual pornography is degrading to women?'
#  'Sexually explicit art or song lyrics should be'
#  'Do you often have strong opinions about the government?'
#  'Would you prefer it if fashion models were the same size and bodytype as the average citizen?'
#  'Do you believe that adults should be able to carry firearms in public?'
#  'Is it logically inconsistent to support the death penalty but oppose abortion?'
#  'Could you date someone who has (and acts on) radical-left politics?'
#  'Should healthcare be funded by the government?'
#  "Which of the following 'solutions' do you think would provide the biggest reduction in crime rates?"
#  'Would you be willing to pay for good sex?'
#  'Do you think safe sex should be taught in schools?'
#  'If someone identifies as a feminist, does that raise or lower your opinion of them?'
#  'Do you believe that illegal residents should be deported from your country?'
#  'Do you think angry or pornographic music lyrics should be kept, by law, away from kids?'
#  'Has Christianity made the world better or worse?'
#  'How do you describe yourself politically?'
#  'Would you fight for your country in an unjust war?'
#  'Politically, which way do you lean?'
#  'Should drugs be legalized, regulated, and taxed?'
#  'Should cigarettes be illegal?'
#  'Hypothetically, if you had an unwanted child on the way, what would you do?'
#  'Which would you rather drive?'
#  'Do most politicians really want to make the world a better place?'
#  'If someone murdered a close friend of yours, would you hope for the death penalty?'
#  'If there were a political candidate who you really liked, how would you offer support in terms of time or money?'
#  'If political candidates supported marijuana legalization, how would that affect your disposition toward voting for them?'
#  'Do you believe that, when a soldier kills an enemy soldier in combat during a war, it is murder?'
#  'Do you think boys should be circumcised?'
#  'Would you support assisted suicide/right-to-die legislation?'
#  'On a global scale, which do you believe provides the greater hindrance to world peace and unity?'
#  'Would it bother you if your boss was a minority, female, or gay?'
#  'Would it be a good idea to pass a law requiring people to take a course and pass a test before being allowed to have a child?'
#  'Which is more important in determining whether someone should be your friend?'
#  'Imagine that after becoming romantically involved with someone, they reveal that they formerly earned a living as a prostitute.  How would you react to this new information?'
#  'Should public masturbation be considered a crime?'
#  'Do you think the government has the right to regulate the ownership and use of weapons?'
#  'Which of the following is the most admirable endeavor?'
#  'Overall, do you think feminism has had a positive or negative impact on human civilization?'
#  'Would you sign a prenup?'
#  'Imagine that scientists create a new drug.  When swallowed as a pill, it will completely and permanently eliminate feelings of guilt for prior events.  Testing reveals that there are no harmful medical side effects.  How should this pill be distributed?'
#  'Should sex education be given to children under 15?'
#  'Do you think the public should have access to any literature, regardless of its content?'
#  'If a police officer is found guilty of a crime, do you believe the punishment should be more or less severe than for the average citizen?'
#  'Should governments control population by placing legal limits on childbearing?'
#  "How does finding out someone has served in their country's military affect your respect for them?"
#  'Do you believe that humans are the most important animal species on earth?'
#  'Is it morally right for society to allow parents of children too young to make their own decisions to deny them the medical attention they require for survival for religious reasons?'
#  'Should convicted child molesters have to put up signs in their yards saying what they did?'
#  'Should only those who pay taxes be allowed to vote?'
#  'What is more important to humanity:'
#  'Would it bother you if a date made gender-biased remarks?'
#  'People who are convicted of morally heinous crimes (child molestors, for example) deserve to have bad things happen to them in prison.'
#  'Do you believe that your government should fund embryonic stem cell research that would require the destruction of additional human embryos?'
#  'If a government were brutally oppressing you, what would you do?'
#  'Which biological parent should have legal decision-making power in abortion decisions?'
#  'Overall, what is a more valuable and worthy goal for society?'
#  'Should drunk drivers who kill people in auto crashes face the death penalty?'
#  'Assuming you were in the position to do so and asked to make the final decision, would you launch nuclear weapons under any circumstance?'
#  "Someone offers to give you $100 if you *don't* vote in the next national election. (for example, the US President)  Do you take the money?"
#  'Protesting for civil rights issues is...'
#  'Do you believe the government should be allowed to keep anything secret?'
#  "How should people spell 'women'?"
#  'Should governments be allowed to censor the media in order to protect their citizens?'
#  "Is supporting 'the troops' the same thing as supporting a war (or conflict)?"
#  "Is it ok for men to be 'househusbands'?" 'Are you racist?'
#  'Graffiti that is done without permission of the owner is:'
#  'What do you feel should be the minimum age at which a child should be allowed to drink an alcoholic beverage under the supervision of a parent?  Choose the category that contains your answer.'
#  'At what age is it appropriate to talk to your children about non-traditional relationships (e.g., homosexuality)?'
#  "Imagine you overhear the sounds of domestic physical violence coming from someone else's house or apartment.  How would you respond?"
#  'Would you try to create a child if you understood there to be a 1-in-4 chance it would be born with a major defect?'
#  'In terms of animal rights, do you believe that all species should be equally protected by law?'
#  'If given the chance to vote on a law supporting assisted suicide, how would you cast your vote?'
#  "Should a country always need the UN's approval before declaring war?"
#  'Most claims of sexual harrassment in the workplace are LIES made up by a scorned woman.'
#  'Would you inform law enforcement agencies about a friend committing a serious crime?'
#  "How willing would you be to sacrifice your life in order to save your country's Head of State (eg. Queen or President)"
#  'Do you think people who are in the armed forces deserve special treatment?'
#  'Is it acceptable for a country to spend more money on its defense program, military, or war budget than on its education or welfare programs?'
#  'Do you think it is acceptable to smoke tobacco in front of children?'
#  "What's more important?"
#  'Based on its involvement in world affairs (past and present), do you think the United States deserves to get attacked by terrorists?'
#  'Who has the more honorable profession: a teacher who cultivates young minds or a soldier who defends your country?'
#  "Do you agree with the statement 'everyone's a little racist'?"
#  'Some animal-rights campaigners use violent methods to achieve their goals.  Do you feel they are justified in doing so?'
#  'Do you consider government taxes (such as income tax) a form of theft?'
#  'Do you think taxes are justified?'
#  'Should adults be required by law to wear seatbelts when riding as passengers in automobiles?'
#  'Do you approve of public nudity?'
#  'Overall, do you think men should act more like women, or women should act more like men?'
#  'Do you think the standard of western morality has declined in the last thirty years?'
#  "Imagine a child is in hospital and needs life-saving treatment, but the child's parents withold permission for the treatment for reasons based on their faith. Which do you think is better?"
#  'Do you think that a fourteen year old who commits a violent crime should be tried and punished as an adult?'
#  "Do you believe that people should take a 'parental fitness' test before being allowed to reproduce?"
#  'If you were otherwise willing to enter into a marriage or life-long partnership, would you consider signing a prenuptial or equivalent agreement at the request of your partner?'
#  'Do you think parents who smoke in cars with very young children should be punished?'
#  'Homeschooling is...'
#  'Should pharmacies be allowed to sell preparations that you can take to commit painless and effective suicide?'
#  'Do you think that people who go to jail for serious crimes deserve a second chance out in the real world?'
#  'Should frontal nudity be allowed on non-pay television?' 'Hippies?'
#  'How do you feel about nations spending billions of dollars on space exploration?'
#  'Would you consider dating someone who works in a job that involves animal testing for medical purposes?'
#  "'Those who would sacrifice liberty for security deserve neither.'  Do you agree with this statement?"
#  'War.  What is it good for?'
#  'People should not have children unless they are financially secure.  Do you agree?'
#  "If a man hits a woman for reasons other than self defense, it's generally considered abuse. If a woman hits a man for reasons other than self defense, it's:"
#  "Would you consider voting for a candidate from outside your own political party if they seemed superior to your party's own candidate?"
#  'Which cause is most appealing to you?'
#  'Do you think children should be allowed to play with toy guns?'
#  'Animal Testing.'
#  'Should it be socially acceptable for women have the choice/right to be topless in any area where it is ok for men to be topless?'
#  'Do you believe that intelligence is a basis upon which we should decide how to treat other living creatures?'
#  'The survival of another species should be...'
#  'A child injures himself after trying to reenact a dangerous move he saw on a T.V. show.  Who should be held MOST responsible?'
#  'In some locations, TV networks use warning systems to flag sexual, violent and profain content in programs so parents can better protect children.  Do you think similar warnings should exist for religious content?'
#  'Do you subscribe to/believe in the philosophies of Ayn Rand?'
#  'What is your attitude toward service-industry/hospitality professionals (waitstaff, bellhops, valets, etc.)?'
#  'Do you believe that victims of sex crimes have an obligation to report these crimes to the police?'
#  'Which is more respectable, a sense of responsibility towards others, or a willful sense of individualism?'
#  'Should the government censor publicly broadcast television and radio shows for profane language?'
#  'The diamond dependent economy of West Africa causes civil wars and crimes against humanity. Should people consider this when purchasing or receiving an engagement ring?'
#  'Should a limit be placed on how many children a family can have?'
#  'In order to reduce crime, is it more effective to mandate harsher punishments or tackle the social and economic causes?'
#  'Would you cut off your own good hand, if you knew it would magically solve poverty in the world?'
#  'A first date has gone relatively well so far.  You discover that your date has absolutely no awareness of any significant current affairs from the last month. How might this make you feel?'
#  'Are you more concerned about possibility of being killed as a result of a terrorist attack or a traffic accident?'
#  'Imagine that your government asks every single citizen to provide a DNA sample to be archived.  Would you support this?'
#  'Politics: Should the US be forced to abide by the WOMD rules it sets for other countries? This includes biological, nuclear and other weapons of mass destruction that the US claims to have a right to have.'
#  'What is your opinion on acts of spreading propaganda to vilify political candidates?'
#  'Do you believe that women should be allowed to serve in the military in a front line capacity?  (i.e. infantry, etc.)'
#  'Many people who are homeless have jobs.  Assuming a person is not a substance abuser, do you think the law should punish their employers for not providing a living wage?'
#  'Would you consider dating someone who conducts important medical research, but the research causes pain to laboratory animals?'
#  "You come home and discover that somebody's broken into your house, and they're still inside.  You..."
#  "Of the joke 'A white man is driving a car.  A black man crosses the road, and is struck by the car, entering it through the window.  The black man is charged with breaking and entering', which of the following statements is true:"
#  'Would you give the police significantly more power, if it would lower crime rates?'
#  'How do you feel about nuclear energy?'
#  "Let's say you don't agree with a law, one that won't change. Which is your responsibility?"
#  'What do you think of the government using cameras for surveillance in public areas?'
#  'Are you in favor of age restrictions on drinking alcohol?'
#  'Do you condone speeding and/or racing on public roads (in a car or motorcycle)?'
#  "Do you believe that a major goal of educational systems should be to make people 'better members of society'?"
#  'In the absense of major predators, do you support population control for large herbivores such as deer or buffalo?'
#  'If you could save the life of an obscure endangered creature, or make a multi-million dollar profit, which would you choose?'
#  'Should freedom of speech allow the expression of all viewpoints, even extreme and widely-offensive ones?'
#  'Generally speaking, do you believe that violent revolution is a legitimate method of effecting fundamental social, political, and economic change?'
#  'Should women be just as likely to be drafted during a major war as men are?'
#  "Do you think it is a good idea to use subdermal implants, which provide indentifying information, inside children's bodies?"
#  'Should law enforcement be allowed to lie to suspects during interrogation?'
#  'Should college instructors/professors be allowed to voice their political opinions in class?'
#  'It is more worthwhile and satisfying to:'
#  'Dwight D. Eisenhower once said that every gun that is made, every warship launched, every rocket fired, signifies in the final sense a theft from those who hunger and are not fed, those who are cold and are not clothed. Do you agree?'
#  "Are you familiar with the concept of 'sexuality continuum'?"
#  'Should machines that demonstrate human or higher levels of intelligence be granted legal rights?'
#  'Art Crimes such as grafitti and other public visual expressions are..'
#  'Do you think Christians are persecuted in the U.S.?'
#  'What do you think about downloading pirated music/videos off the internet?'
#  'If there were no welfare programs available in your community, which would you choose to help?'
#  'Do you think the family of a murder victim should have any say in what punishment is given to the murderer?'
#  'Consider the following three pairs of concepts.  Which of the three pairs do you find to be the most contradictory?'
#  'Do you think politics have an impact on your everyday life?'
#  'Which is more effective, militant action or peaceful protest?'
#  'Would you risk your life to protest against an unjust government?'
#  'Is it wrong for two adopted siblings to date each other?'
#  "Which do you think is more important in today's world?"
#  'Do you think that the psychological differences between human males and females are better explained by nature or nurture?'
#  'Would you support a system that would allow people to be free to live and work in any country in the world regardless of their citizenship or nation of birth?'
#  'Do you feel that voting in all elections should be required by law?'
#  "Do you think advanced primates, like chimps and apes, should be afforded some degree of 'human' rights?"
#  'Do you condone free file sharing - even if it violates copyright policies?'
#  'Do you think that wealthy nations have a responsibility to assist developing nations?'
#  'Should people seeking to adopt children be required by law to pass a parenting course prior to being allowed to adopt?'
#  'Do you feel that a major reduction of the human population is necessary for the long-term survival of the Earth?'
#  'If you discovered that something you do is bad for the environment, would you be willing to sacrifice your time or money to correct the problem?'
#  'Should laws that address nudity above the waist apply equally to males and females?'
#  'A company should be free to hire any worker it chooses.'
#  'Would you be willing to use deadly force to prevent an unwarranted search of your home by government officials?'
#  "Do you believe the state of Earth's climate is your personal responsibility?"
#  'Imagine a law is passed that makes one of your favorite activities illegal.  Assuming you believe the activity to be harmless, would you continue pursuing it if there exists a high probability of eventually being caught?'
#  'Do you think most people are too politically correct or too politically incorrect?'
#  'Should people be allowed to sell their body parts, organs, and tissues for profit?'
#  'Which better explains why most homeless people are homeless?'
#  'Do you think it is a good idea for a single person to try to create or adopt a child and raise it on his or her own?'
#  'You have a chance to save the last members of an ancient human culture or the last breeding pair of an endangered species.  Whichever you do not save WILL die and will be lost forever.  Which one do you save?'
#  'Do you find it fair that under national emergencies leaders are escorted to extreme safety while the majority of the public is at risk?'
#  'Would you find it easier to kill for your beliefs or to die for them?'
#  'Do you think the media, in general, is too conservative, too liberal, or actually pretty impartial?'
#  'Is nearly seven billion living humans too many?'
#  'Do you believe that there should be laws to explicitly protect freedom of religion?'
#  "Agree or disagree: 'The needs of the many outweigh the needs of the few (or the one).'"
#  'I would rather vote for a candidate whose policies significantly:'
#  'Do you believe that wealth in America is fairly distributed?'
#  'Would it be useful and ethical to clone the best and brightest of our species, for the common good? (Assuming we can get the success rate pretty high.)'
#  'Would you consider donating your body to science after you die?'
#  "The following quote has been attributed to the ancient Greek philosopher Socrates, who lived from 470 BC - 399 BC: 'Thou shouldst eat to live, not live to eat.'  Do you agree with this philosophy?"
#  'Can intelligence be quantified or measured?'
#  'Is abortion okay if a woman is raped?'
#  'Homosexuality is illegal in many countries, with penalties including fines, imprisonment, flogging, and death. Do you feel homosexuality should be illegal in your own country?']
#                                                          text  \
# Unnamed: 0
# q34113      How do you feel about government-subsidized fo...
# q179268                   Are you either vegetarian or vegan?
# q403                        Do you enjoy discussing politics?
# q175           Should burning your country's flag be illegal?
# q212813          Which best describes your political beliefs?
#
#                        option_1                        option_2  \
# Unnamed: 0
# q34113               No problem  It's okay, if it is not abused
# q179268                     Yes                              No
# q403                        Yes                              No
# q175                        Yes                              No
# q212813     Liberal / Left-wing                        Centrist
#
#                                   option_3           option_4      N Type  \
# Unnamed: 0
# q34113      Okay for short amounts of time  Never - Get a job  31769    O
# q179268                                NaN                NaN  54202    O
# q403                                   NaN                NaN  52369    O
# q175                                   NaN                NaN  45720    O
# q212813          Conservative / Right-wing              Other  45107    M
#
#            Order                           Keywords  n_answers
# Unnamed: 0
# q34113       NaN                           politics    68371.0
# q179268      NaN              politics; descriptive    54202.0
# q403         NaN  politics; preference; descriptive    52369.0
# q175         NaN                           politics    45720.0
# q212813      [4]              politics; descriptive    45107.0

# %% [markdown]
# ### Descriptive questions

# %%
# find descriptive questions
descriptive_questions = question_data[question_data.Keywords == 'descriptive']
print(f'number of questions with keyword descriptive: {descriptive_questions.shape[0]}')

# sort descriptive questions
sorted_d_questions = descriptive_questions.sort_values(by=['n_answers'], ascending=False)
# extract 10 most answered descriptive questions and target question about politcal orientation ('q212813')
questions_all = descriptive_questions.index.to_list()
questions_top_50 = sorted_d_questions[:50].index.to_list() 
print(sorted_d_questions['text'][:50].values)
display(sorted_d_questions[:50])
# Out:
# number of questions with keyword descriptive: 829
# ['Do you like watching foreign movies with subtitles?'
#  'Which type of wine would you prefer to drink outside of a meal, such as for leisure?'
#  'Have you smoked a cigarette in the last 6 months?'
#  'Do you enjoy intense intellectual conversations?'
#  'Rate your self-confidence:' 'Are you happy with your life?'
#  'How frequently do you drink alcohol?'
#  "What's your deal with harder drugs (stuff beyond pot)?"
#  'Which word describes you better?'
#  "What's your relationship with marijuana?"
#  'How often do you keep your promises?'
#  'How often are you open with your feelings?'
#  'How often do you brush your teeth?'
#  'If you had to name your greatest motivation in life thus far, what would it be?'
#  'Do you often make jokes that offend more uptight people?'
#  'How much influence or control do your parents have over your life?'
#  'How important are your political beliefs to you?'
#  'Do you space out or daydream a lot?'
#  'Do you keep a budget (of your finances)?'
#  'How do you feel about documentaries?'
#  "If you don't do anything at all for an entire day, how does that make you feel?"
#  'How frequently do you bathe or shower?'
#  'If you were to die, would whoever goes through your personal belongings be shocked by what they find?'
#  'How long do your romantic relationships usually last?'
#  'How often do you meditate?' 'Do you have any tattoos?'
#  'Are you an aspiring actor/artist/writer or other creative type?'
#  'Are you looking for a partner to have children with?'
#  'Are you careful with your money?'
#  'Which of the following best describes your typical demeanor?'
#  'On average, which best describes how often you GET WICKED DRUNK?'
#  'If you like someone a lot, do you usually ask them out?'
#  'How often do you get angry?'
#  "Do you say 'Thank you' to wait staff when served in a restaurant?"
#  'Outside of work and school, how inclined are you to investigate something that interests you?'
#  'Regardless of your actual age, do you consider yourself to be an adult?'
#  'Do you litter?'
#  'Are you ready to settle down and get married right now?'
#  'If it were legal to do so where you live, would you smoke marijuana?'
#  'Were you picked on a lot in school?'
#  'Are you an adventurous eater? Do you like to try new foods and ethnic cuisines?'
#  "You're dating someone new. You discover that they have a housemate the same sex as you. This:"
#  'When you are angry or frustrated, do you ever throw, smash, kick, hit inanimate objects (non-living things)?'
#  'Do you often find yourself worrying about things that you have no control over?'
#  "'Your a bitch!' What bothers you more about the above sentence?"
#  'How frequently do you go out of your way to make others feel appreciated?'
#  'Would you consider living with a partner who does not want any pets?'
#  "How much do you go 'clubbing' (out dancing in bars)?"
#  'How often do you do things out of spite?' 'Are you currently employed?']
#                                                          text  \
# Unnamed: 0
# q416235     Do you like watching foreign movies with subti...
# q85419      Which type of wine would you prefer to drink o...
# q501        Have you smoked a cigarette in the last 6 months?
# q358084      Do you enjoy intense intellectual conversations?
# q20930                             Rate your self-confidence:
# q4018                           Are you happy with your life?
# q77                      How frequently do you drink alcohol?
# q80         What's your deal with harder drugs (stuff beyo...
# q49                          Which word describes you better?
# q79                  What's your relationship with marijuana?
# q29829                   How often do you keep your promises?
# q35660             How often are you open with your feelings?
# q12970                     How often do you brush your teeth?
# q18834      If you had to name your greatest motivation in...
# q23834      Do you often make jokes that offend more uptig...
# q43261      How much influence or control do your parents ...
# q212814      How important are your political beliefs to you?
# q20725                    Do you space out or daydream a lot?
# q20418               Do you keep a budget (of your finances)?
# q416236                  How do you feel about documentaries?
# q442        If you don't do anything at all for an entire ...
# q1062                  How frequently do you bathe or shower?
# q40441      If you were to die, would whoever goes through...
# q19874      How long do your romantic relationships usuall...
# q53611                             How often do you meditate?
# q128                                 Do you have any tattoos?
# q158        Are you an aspiring actor/artist/writer or oth...
# q80041      Are you looking for a partner to have children...
# q16713                       Are you careful with your money?
# q1707       Which of the following best describes your typ...
# q8155       On average, which best describes how often you...
# q308        If you like someone a lot, do you usually ask ...
# q1052                             How often do you get angry?
# q45428      Do you say 'Thank you' to wait staff when serv...
# q24282      Outside of work and school, how inclined are y...
# q53540      Regardless of your actual age, do you consider...
# q17017                                         Do you litter?
# q36045      Are you ready to settle down and get married r...
# q62254      If it were legal to do so where you live, woul...
# q313640                   Were you picked on a lot in school?
# q32973      Are you an adventurous eater? Do you like to t...
# q26557      You're dating someone new. You discover that t...
# q23696      When you are angry or frustrated, do you ever ...
# q27477      Do you often find yourself worrying about thin...
# q30416      'Your a bitch!' What bothers you more about th...
# q26841      How frequently do you go out of your way to ma...
# q83646      Would you consider living with a partner who d...
# q81         How much do you go 'clubbing' (out dancing in ...
# q39373               How often do you do things out of spite?
# q8865                             Are you currently employed?
#
#                                          option_1  \
# Unnamed: 0
# q416235                                       Yes
# q85419      White (such as Chardonnay, Riesling).
# q501                                          Yes
# q358084                                       Yes
# q20930                            Very, very high
# q4018                                         Yes
# q77                                    Very often
# q80                         I do drugs regularly.
# q49                                      Carefree
# q79                            I smoke regularly.
# q29829                                     Always
# q35660                                     Always
# q12970                        Twice or more a day
# q18834                                       Love
# q23834                                        Yes
# q43261                        I am my own person.
# q212814                            Very important
# q20725                               All the time
# q20418                                        Yes
# q416236                                      Yay!
# q442                                         Good
# q1062                        At least once a day.
# q40441                                       Yes.
# q19874                                 0-6 months
# q53611                                Frequently.
# q128                 I have 1 or more BIG tattoos
# q158                                          Yes
# q80041                                        Yes
# q16713                                        Yes
# q1707       Cheerful!  I have a positive outlook.
# q8155                        Twice a week or more
# q308                                          Yes
# q1052                                  Very often
# q45428                                    Always.
# q24282                              Very inclined
# q53540                                       Yes.
# q17017                                      Often
# q36045                                Absolutely.
# q62254                                       Yes.
# q313640                                       Yes
# q32973                         Yes, all the time.
# q26557               Makes you feel uncomfortable
# q23696                            Yes, frequently
# q27477                                        Yes
# q30416                              The profanity
# q26841                      Way more than average
# q83646                                       Yes.
# q81                                          Lots
# q39373                                Very often.
# q8865                  Yes, I have a fulltime job
#
#                                                option_2  \
# Unnamed: 0
# q416235                                              No
# q85419          Red (such as Merlot, Cabernet, Shiraz).
# q501                                                 No
# q358084                                              No
# q20930                              Higher than average
# q4018                                                No
# q77                                           Sometimes
# q80                            I do drugs occasionally.
# q49                                             Intense
# q79                               I smoke occasionally.
# q29829                                Whenever possible
# q35660                                          Usually
# q12970                                       Once a day
# q18834                                           Wealth
# q23834                                               No
# q43261      I consider their opinion but go my own way.
# q212814                              Somewhat important
# q20725                                   Rarely / never
# q20418                                               No
# q416236                                            Okay
# q442                                                Bad
# q1062                      Usually daily.  I skip some.
# q40441                                              No.
# q19874                                      6-12 months
# q53611                                          Rarely.
# q128                    I have 1 or more LITTLE tattoos
# q158                                                 No
# q80041                                               No
# q16713                                               No
# q1707                     Meh. I have my ups and downs.
# q8155                                Weekly / Bi-Weekly
# q308                                                 No
# q1052                                         Sometimes
# q45428                                Most of the time.
# q24282                                Somewhat inclined
# q53540                                              No.
# q17017                                           Rarely
# q36045                                          No way.
# q62254                                              No.
# q313640                                              No
# q32973                    Yes, if it's not too strange.
# q26557                         Doesn't faze you one bit
# q23696                                        Sometimes
# q27477                                               No
# q30416                                      The grammar
# q26841                                    About average
# q83646                                              No.
# q81                                           Sometimes
# q39373                                       Sometimes.
# q8865                                                No
#
#                                                      option_3  \
# Unnamed: 0
# q416235                       Can't answer without a subtitle
# q85419                        Rosé (such as White Zinfindel).
# q501                                                      NaN
# q358084                                                   NaN
# q20930                                                Average
# q4018                                                     NaN
# q77                                                    Rarely
# q80               I've done drugs in the past, but no longer.
# q49                                                       NaN
# q79                      I smoked in the past, but no longer.
# q29829                                                Usually
# q35660                                                 Rarely
# q12970                            Only on days I feel like it
# q18834                                             Expression
# q23834                                                    NaN
# q43261      I almost always do what my parents think is best.
# q212814                                    A little important
# q20725                                              Sometimes
# q20418                                              Sometimes
# q416236                                                   NO.
# q442                                                      NaN
# q1062                                  A couple times a week.
# q40441                                    Maybe a little bit.
# q19874                                             12+ months
# q53611                                                 Never.
# q128                                        I have no tattoos
# q158                                                      NaN
# q80041                                                    NaN
# q16713                                                    NaN
# q1707                               Annoyed. The world sucks.
# q8155                              Once every month or three.
# q308                                                      NaN
# q1052                                                  Rarely
# q45428                                          Occasionally.
# q24282                                           Not inclined
# q53540                                 Only some of the time.
# q17017                                                  Never
# q36045                       Get married yes, settle down no.
# q62254                                                    NaN
# q313640                                                   NaN
# q32973                        On rare occasions/I don't know.
# q26557                                                    NaN
# q23696                              Used to, but not any more
# q27477                                                    NaN
# q30416                            They both bother me equally
# q26841                              Less than average / Never
# q83646                                                    NaN
# q81                                                    Rarely
# q39373                                                Rarely.
# q8865                                               Part time
#
#                                      option_4      N Type         Order  \
# Unnamed: 0
# q416235                                   NaN  20364    O       3, 1, 2
# q85419                    I don't drink wine.  18838    N           NaN
# q501                                      NaN  57123    O           NaN
# q358084                                   NaN  54696    O           NaN
# q20930                          Below average  53737    O           NaN
# q4018                                     NaN  53625    O           NaN
# q77                                     Never  52467    O           NaN
# q80                         I never do drugs.  50107    O           NaN
# q49                                       NaN  49827    N           NaN
# q79                                    Never.  49796    O           NaN
# q29829                        When convenient  49564    O           NaN
# q35660                                  Never  49489    O           NaN
# q12970                         Rarely / never  47673    O           NaN
# q18834                              Knowledge  46158    N           NaN
# q23834                                    NaN  44922    O           NaN
# q43261       I always do what my parents say.  44620    O           NaN
# q212814                  Not at all important  44143    O           NaN
# q20725                                    NaN  43906    O           NaN
# q20418                                    NaN  43634    O       2, 3, 1
# q416236                                   NaN  43521    O           NaN
# q442                                      NaN  41784    O           NaN
# q1062                    Once a week or less.  41649    O           NaN
# q40441                                    NaN  41572    O       2, 3, 1
# q19874      I've never been in a relationship  40948    M           [4]
# q53611                                    NaN  40623    O           NaN
# q128                                      NaN  40450    O           NaN
# q158                                      NaN  40052    O           NaN
# q80041                                    NaN  40026    O           NaN
# q16713                                    NaN  39863    O           NaN
# q1707                                     NaN  38613    O           NaN
# q8155                        Seldom or never.  38298    O           NaN
# q308                                      NaN  37597    O           NaN
# q1052                                     NaN  37223    O           NaN
# q45428                                 Never.  36781    O           NaN
# q24282                                    NaN  35888    O           NaN
# q53540                                    NaN  35857    O       2, 3, 1
# q17017                                    NaN  35221    O           NaN
# q36045       Get married no, settle down yes.  35186    O  2, (3, 4), 1
# q62254                                    NaN  34257    O           NaN
# q313640                                   NaN  34128    O           NaN
# q32973                              No, yuck.  33661    O           NaN
# q26557                                    NaN  33640    O           NaN
# q23696                                  Never  33272    O           NaN
# q27477                                    NaN  33120    O           NaN
# q30416                 Neither one bothers me  32676    O  3, (1, 2), 4
# q26841                                    NaN  32376    O           NaN
# q83646                                    NaN  32223    O           NaN
# q81                                     Never  31984    O           NaN
# q39373                                 Never.  31964    O           NaN
# q8865                           I'm a student  31950    M  2, 3, 1, [4]
#
#                Keywords  n_answers
# Unnamed: 0
# q416235     descriptive    68371.0
# q85419      descriptive    68371.0
# q501        descriptive    57123.0
# q358084     descriptive    54696.0
# q20930      descriptive    53737.0
# q4018       descriptive    53625.0
# q77         descriptive    52467.0
# q80         descriptive    50107.0
# q49         descriptive    49827.0
# q79         descriptive    49796.0
# q29829      descriptive    49564.0
# q35660      descriptive    49489.0
# q12970      descriptive    47673.0
# q18834      descriptive    46158.0
# q23834      descriptive    44922.0
# q43261      descriptive    44620.0
# q212814     descriptive    44143.0
# q20725      descriptive    43906.0
# q20418      descriptive    43634.0
# q416236     descriptive    43521.0
# q442        descriptive    41784.0
# q1062       descriptive    41649.0
# q40441      descriptive    41572.0
# q19874      descriptive    40948.0
# q53611      descriptive    40623.0
# q128        descriptive    40450.0
# q158        descriptive    40052.0
# q80041      descriptive    40026.0
# q16713      descriptive    39863.0
# q1707       descriptive    38613.0
# q8155       descriptive    38298.0
# q308        descriptive    37597.0
# q1052       descriptive    37223.0
# q45428      descriptive    36781.0
# q24282      descriptive    35888.0
# q53540      descriptive    35857.0
# q17017      descriptive    35221.0
# q36045      descriptive    35186.0
# q62254      descriptive    34257.0
# q313640     descriptive    34128.0
# q32973      descriptive    33661.0
# q26557      descriptive    33640.0
# q23696      descriptive    33272.0
# q27477      descriptive    33120.0
# q30416      descriptive    32676.0
# q26841      descriptive    32376.0
# q83646      descriptive    32223.0
# q81         descriptive    31984.0
# q39373      descriptive    31964.0
# q8865       descriptive    31950.0

# %% [markdown]
# ### Extract answered descriptive Questions and political orientation

# %%
# create dataframe of descriptive questions and political belief
descriptive_df = data[questions_all + [political_belief]]
descriptive_df = descriptive_df[descriptive_df[political_belief].notna()]
print(f'Number of people who answered some of the descriptive questions and their political belief: {descriptive_df.shape}')
# Out:
# Number of people who answered some of the descriptive questions and their political belief: (45107, 830)

# %% [markdown]
# ### Split into Train and Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(data, shuffle=True, test_size=0.2, random_state=42)
df_train.to_parquet(os.path.join(root_path, 'train.parquet'))
df_test.to_parquet(os.path.join(root_path, 'test.parquet'))

# %%
df_train, df_test = train_test_split(descriptive_df, shuffle=True, test_size=0.2, random_state=42)
#df_train.to_parquet(os.path.join(root_path, 'train_descriptive.parquet'))
#df_test.to_parquet(os.path.join(root_path, 'test_descriptive.parquet'))

# %% [markdown]
# ## Model 1: Inlcude the 10 most answered desctiptive questions as predictors:

# %%
df_train = pd.read_parquet(os.path.join(root_path, 'train.parquet'))
df_test = pd.read_parquet(os.path.join(root_path, 'test.parquet'))

# %%
df_train_top_50 = df_train[questions_top_50 + [political_belief]].dropna() # remove rows with NaN Values 
df_test_top_50= df_test[questions_top_50 + [political_belief]].dropna() # remove rows with NaN Values 
# TODO: think about political view 'other' What do we want to do with that?

print('shape train set:', df_train_top_50.shape)
display(df_train_top_50[:10])
# Out:
# shape train set: (9777, 51)
#                                q416235  \
# index
# 21628  Can't answer without a subtitle
# 51271  Can't answer without a subtitle
# 57902                               No
# 31176  Can't answer without a subtitle
# 26531                              Yes
# 20044  Can't answer without a subtitle
# 24454  Can't answer without a subtitle
# 24735                              Yes
# 25863  Can't answer without a subtitle
# 59583                              Yes
#
#                                         q85419 q501 q358084  \
# index
# 21628  Red (such as Merlot, Cabernet, Shiraz).  Yes     Yes
# 51271  Red (such as Merlot, Cabernet, Shiraz).  Yes     Yes
# 57902                      I don't drink wine.  Yes     Yes
# 31176                      I don't drink wine.  Yes     Yes
# 26531    White (such as Chardonnay, Riesling).   No     Yes
# 20044          Rosé (such as White Zinfindel).   No     Yes
# 24454          Rosé (such as White Zinfindel).   No     Yes
# 24735  Red (such as Merlot, Cabernet, Shiraz).   No     Yes
# 25863                      I don't drink wine.   No     Yes
# 59583  Red (such as Merlot, Cabernet, Shiraz).   No     Yes
#
#                     q20930 q4018        q77  \
# index
# 21628  Higher than average   Yes     Rarely
# 51271  Higher than average   Yes  Sometimes
# 57902  Higher than average   Yes      Never
# 31176  Higher than average   Yes     Rarely
# 26531              Average   Yes  Sometimes
# 20044              Average   Yes  Sometimes
# 24454  Higher than average    No     Rarely
# 24735              Average    No  Sometimes
# 25863              Average   Yes  Sometimes
# 59583  Higher than average   Yes     Rarely
#
#                                                q80       q49  \
# index
# 21628                            I never do drugs.  Carefree
# 51271                            I never do drugs.  Carefree
# 57902  I've done drugs in the past, but no longer.   Intense
# 31176  I've done drugs in the past, but no longer.  Carefree
# 26531                            I never do drugs.  Carefree
# 20044  I've done drugs in the past, but no longer.   Intense
# 24454                            I never do drugs.  Carefree
# 24735                            I never do drugs.   Intense
# 25863                            I never do drugs.   Intense
# 59583                            I never do drugs.  Carefree
#
#                                         q79  ...  \
# index                                        ...
# 21628                                Never.  ...
# 51271                 I smoke occasionally.  ...
# 57902  I smoked in the past, but no longer.  ...
# 31176  I smoked in the past, but no longer.  ...
# 26531                                Never.  ...
# 20044                 I smoke occasionally.  ...
# 24454                                Never.  ...
# 24735                                Never.  ...
# 25863  I smoked in the past, but no longer.  ...
# 59583                                Never.  ...
#
#                              q26557                     q23696 q27477  \
# index
# 21628      Doesn't faze you one bit                      Never    Yes
# 51271  Makes you feel uncomfortable                  Sometimes    Yes
# 57902      Doesn't faze you one bit                      Never     No
# 31176      Doesn't faze you one bit  Used to, but not any more     No
# 26531      Doesn't faze you one bit  Used to, but not any more     No
# 20044      Doesn't faze you one bit                  Sometimes    Yes
# 24454  Makes you feel uncomfortable  Used to, but not any more    Yes
# 24735      Doesn't faze you one bit                      Never    Yes
# 25863      Doesn't faze you one bit                  Sometimes    Yes
# 59583      Doesn't faze you one bit                  Sometimes    Yes
#
#                             q30416                 q26841 q83646        q81  \
# index
# 21628                The profanity          About average   Yes.  Sometimes
# 51271       Neither one bothers me  Way more than average   Yes.     Rarely
# 57902                  The grammar          About average   Yes.      Never
# 31176                  The grammar  Way more than average   Yes.      Never
# 26531                  The grammar  Way more than average   Yes.     Rarely
# 20044                  The grammar  Way more than average    No.     Rarely
# 24454                  The grammar          About average   Yes.      Never
# 24735                  The grammar  Way more than average   Yes.  Sometimes
# 25863  They both bother me equally          About average   Yes.       Lots
# 59583                  The grammar  Way more than average   Yes.     Rarely
#
#            q39373                       q8865                    q212813
# index
# 21628  Sometimes.  Yes, I have a fulltime job                      Other
# 51271  Sometimes.  Yes, I have a fulltime job                      Other
# 57902     Rarely.  Yes, I have a fulltime job  Conservative / Right-wing
# 31176      Never.                          No        Liberal / Left-wing
# 26531     Rarely.  Yes, I have a fulltime job        Liberal / Left-wing
# 20044     Rarely.  Yes, I have a fulltime job        Liberal / Left-wing
# 24454  Sometimes.                   Part time                   Centrist
# 24735      Never.                          No  Conservative / Right-wing
# 25863  Sometimes.  Yes, I have a fulltime job                      Other
# 59583      Never.  Yes, I have a fulltime job  Conservative / Right-wing
#
# [10 rows x 51 columns]

# %% [markdown]
# #### Convert top 10 answers to ordered categorical variabales:

# %%
from pandas.api.types import CategoricalDtype

# %%
questions_top_10 = questions_top_50[:10]
df_train_top_10 = df_train_top_50[questions_top_10+[political_belief]]
df_test_top_10 = df_test_top_50[questions_top_10+[political_belief]]
question_data.loc[questions_top_10].text
# Out:
# Unnamed: 0
# q416235    Do you like watching foreign movies with subti...
# q85419     Which type of wine would you prefer to drink o...
# q501       Have you smoked a cigarette in the last 6 months?
# q358084     Do you enjoy intense intellectual conversations?
# q20930                            Rate your self-confidence:
# q4018                          Are you happy with your life?
# q77                     How frequently do you drink alcohol?
# q80        What's your deal with harder drugs (stuff beyo...
# q49                         Which word describes you better?
# q79                 What's your relationship with marijuana?
# Name: text, dtype: object

# %%
# Create a Displot
ax = sns.displot(df_train_top_10[political_belief], kind='hist', shrink=0.8)

# Set the bin names
ax.set_xticklabels(['Other', 'Right', 'Left', 'Centrist'])
ax.set_xlabels('Political belief')

# Show the plot
plt.show()

# %%
weights=(df_train_top_10.groupby(political_belief)[political_belief].count()/len(df_train_top_10)).to_list()
weights
# Out:
# [0.2012887388769561,
#  0.07977907333537895,
#  0.3743479594967781,
#  0.34458422829088675]

# %%
for question in df_train_top_10.drop(political_belief, axis=1).columns:
    # Create a Displot
    question_title = question_data.loc[question]['text']
    ax = sns.displot(df_train_top_10, x = question, kind='hist', shrink=0.8, col=political_belief, height=5, stat="density")
    # Set the bin names
    #ax.set_xticklabels(['Other', 'Right', 'Left', 'Centrist'])
    #ax.set_xlabels('Political belief')
    ax.fig.suptitle(question_title)
    ax.fig.tight_layout()
    ax.fig.subplots_adjust(top=0.88)
    ax.set_titles("{col_name}")
    ax.fig.set_size_inches(5*len(ax.col_names),5 )
    # Show the plot
    plt.show()

# %% [markdown]
# # Categorize Feature

# %%
options = [column for column in question_data.columns if 'option' in column]
questions_categories = {index: row[options].dropna().tolist()   for index, row in question_data.loc[questions_top_10].iterrows()}
unordered_categories = {k: questions_categories[k] for k in questions_categories.keys() - {'q20930', 'q77', 'q80', 'q79'}}
ordered_categories = {k: questions_categories[k] for k in questions_categories.keys() - unordered_categories.keys()}
print('Categories with no order:\n', unordered_categories)
print('Categories with order:\n', ordered_categories)
# Out:
# Categories with no order:
#  {'q358084': ['Yes', 'No'], 'q4018': ['Yes', 'No'], 'q416235': ['Yes', 'No', "Can't answer without a subtitle"], 'q501': ['Yes', 'No'], 'q85419': ['White (such as Chardonnay, Riesling).', 'Red (such as Merlot, Cabernet, Shiraz).', 'Rosé (such as White Zinfindel).', "I don't drink wine."], 'q49': ['Carefree', 'Intense']}
# Categories with order:
#  {'q20930': ['Very, very high', 'Higher than average', 'Average', 'Below average'], 'q77': ['Very often', 'Sometimes', 'Rarely', 'Never'], 'q80': ['I do drugs regularly.', 'I do drugs occasionally.', "I've done drugs in the past, but no longer.", 'I never do drugs.'], 'q79': ['I smoke regularly.', 'I smoke occasionally.', 'I smoked in the past, but no longer.', 'Never.']}

# %%
for question, categories in unordered_categories.items():
    cat_type = CategoricalDtype(categories=categories)
    df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
    df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)

for question, categories in ordered_categories.items():
    cat_type = CategoricalDtype(categories=categories.reverse(), ordered=True)
    df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
    df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# Out:
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_test_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:8: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:9: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:8: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:9: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:8: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:9: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:8: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_train_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
# /var/folders/x_/zg37n3fn4wn8n2nxhq90dxyw0000gn/T/ipykernel_27651/1535900156.py:9: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_train_top_10.loc[:,question] = df_test_top_10[question].astype(cat_type)
