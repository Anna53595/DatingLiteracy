# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import balanced_accuracy_score, accuracy_score

import pandas as pd
from utils import preprocessing

# %% [markdown]
# # Load Data

# %%
# Load data
questions = pd.read_csv('data/question_data.csv', sep=';')
questions = questions.set_index('Unnamed: 0')  # set first column (question number) as index
df_train = pd.read_parquet('data/train_descriptive.parquet')
df_test = pd.read_parquet('data/test_descriptive.parquet')
political_belief = 'q212813'

# %%
K_max = 30
# K_max questions
selected_questions = ['q212813'] + preprocessing.top_k_questions(keyword='descriptive', k=K_max, questions_df=questions, data=df_train)
df_train_top_kmax = preprocessing.preprocess(df_train[selected_questions])
df_test_top_kmax = preprocessing.preprocess(df_test[selected_questions])
display(df_train_top_kmax)
# Out:
# selected questions:  ['Do you like watching foreign movies with subtitles?'
#  'Which type of wine would you prefer to drink outside of a meal, such as for leisure?'
#  'Do you enjoy intense intellectual conversations?'
#  'Have you smoked a cigarette in the last 6 months?'
#  'How frequently do you drink alcohol?' 'Rate your self-confidence:'
#  'How often do you keep your promises?'
#  'How often are you open with your feelings?'
#  "What's your deal with harder drugs (stuff beyond pot)?"
#  'Are you happy with your life?'
#  "What's your relationship with marijuana?"
#  'If you had to name your greatest motivation in life thus far, what would it be?'
#  'How often do you brush your teeth?'
#  'How important are your political beliefs to you?'
#  'Do you often make jokes that offend more uptight people?'
#  'How much influence or control do your parents have over your life?'
#  'Do you keep a budget (of your finances)?'
#  'Do you space out or daydream a lot?'
#  'How do you feel about documentaries?'
#  "If you don't do anything at all for an entire day, how does that make you feel?"
#  'If you were to die, would whoever goes through your personal belongings be shocked by what they find?'
#  'How often do you meditate?'
#  'How long do your romantic relationships usually last?'
#  'How frequently do you bathe or shower?'
#  'Are you an aspiring actor/artist/writer or other creative type?'
#  'Are you looking for a partner to have children with?'
#  'Do you have any tattoos?' 'Are you careful with your money?'
#  'Which of the following best describes your typical demeanor?'
#  'On average, which best describes how often you GET WICKED DRUNK?']
#                          q212813                          q416235  \
# index
# 31844                   Centrist                              Yes
# 21628                      Other  Can't answer without a subtitle
# 51271                      Other  Can't answer without a subtitle
# 12228        Liberal / Left-wing  Can't answer without a subtitle
# 57902  Conservative / Right-wing                               No
# ...                          ...                              ...
# 26463                   Centrist                              Yes
# 33094        Liberal / Left-wing                              Yes
# 59462        Liberal / Left-wing  Can't answer without a subtitle
# 27366                      Other                               No
# 60546        Liberal / Left-wing                              Yes
#
#                                         q85419 q358084 q501         q77  \
# index
# 31844  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 21628  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes      Rarely
# 51271  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes   Sometimes
# 12228          Rosé (such as White Zinfindel).     Yes   No       Never
# 57902                      I don't drink wine.     Yes  Yes       Never
# ...                                        ...     ...  ...         ...
# 26463                      I don't drink wine.     Yes   No      Rarely
# 33094  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes  Very often
# 59462  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 27366          Rosé (such as White Zinfindel).     Yes   No   Sometimes
# 60546  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
#
#                     q20930             q29829   q35660  \
# index
# 31844              Average  Whenever possible  Usually
# 21628  Higher than average  Whenever possible  Usually
# 51271  Higher than average             Always  Usually
# 12228        Below average  Whenever possible  Usually
# 57902  Higher than average             Always   Always
# ...                    ...                ...      ...
# 26463              Average             Always  Usually
# 33094      Very, very high             Always    Never
# 59462              Average  Whenever possible  Usually
# 27366  Higher than average             Always  Usually
# 60546      Very, very high  Whenever possible   Always
#
#                                                q80  ...               q40441  \
# index                                               ...
# 31844                            I never do drugs.  ...  Maybe a little bit.
# 21628                            I never do drugs.  ...                  No.
# 51271                            I never do drugs.  ...  Maybe a little bit.
# 12228                            I never do drugs.  ...  Maybe a little bit.
# 57902  I've done drugs in the past, but no longer.  ...                  No.
# ...                                            ...  ...                  ...
# 26463                            I never do drugs.  ...                 Yes.
# 33094  I've done drugs in the past, but no longer.  ...                 Yes.
# 59462                     I do drugs occasionally.  ...                 Yes.
# 27366  I've done drugs in the past, but no longer.  ...                  No.
# 60546                            I never do drugs.  ...  Maybe a little bit.
#
#             q53611       q19874                         q1062 q158 q80041  \
# index
# 31844       Never.  6-12 months  Usually daily.  I skip some.  Yes    Yes
# 21628  Frequently.   12+ months  Usually daily.  I skip some.   No    Yes
# 51271      Rarely.   12+ months          At least once a day.  Yes    Yes
# 12228      Rarely.   12+ months          At least once a day.   No     No
# 57902       Never.  6-12 months          At least once a day.   No    Yes
# ...            ...          ...                           ...  ...    ...
# 26463       Never.   12+ months          At least once a day.   No    Yes
# 33094       Never.   12+ months  Usually daily.  I skip some.  Yes     No
# 59462  Frequently.  6-12 months          At least once a day.  Yes     No
# 27366  Frequently.  6-12 months          At least once a day.  Yes    Yes
# 60546  Frequently.  6-12 months          At least once a day.  Yes    Yes
#
#                                q128 q16713  \
# index
# 31844             I have no tattoos     No
# 21628             I have no tattoos    Yes
# 51271  I have 1 or more BIG tattoos    Yes
# 12228             I have no tattoos    Yes
# 57902             I have no tattoos    Yes
# ...                             ...    ...
# 26463             I have no tattoos    Yes
# 33094             I have no tattoos     No
# 59462             I have no tattoos     No
# 27366             I have no tattoos    Yes
# 60546             I have no tattoos    Yes
#
#                                        q1707                       q8155
# index
# 31844          Meh. I have my ups and downs.            Seldom or never.
# 21628  Cheerful!  I have a positive outlook.            Seldom or never.
# 51271  Cheerful!  I have a positive outlook.  Once every month or three.
# 12228          Meh. I have my ups and downs.            Seldom or never.
# 57902  Cheerful!  I have a positive outlook.            Seldom or never.
# ...                                      ...                         ...
# 26463  Cheerful!  I have a positive outlook.            Seldom or never.
# 33094  Cheerful!  I have a positive outlook.          Weekly / Bi-Weekly
# 59462  Cheerful!  I have a positive outlook.  Once every month or three.
# 27366  Cheerful!  I have a positive outlook.            Seldom or never.
# 60546  Cheerful!  I have a positive outlook.            Seldom or never.
#
# [13570 rows x 31 columns]

# %%
df_train_top_kmax.shape, df_test_top_kmax.shape
# Out:
# ((13570, 31), (3334, 31))

# %% [markdown]
# ## 1. Try top 10

# %%
k = 10

# %%
# questions
top_10 = selected_questions[:k]
df_train_top_10 = df_train_top_kmax[top_10]
df_test_top_10 = df_test_top_kmax[top_10]
display(df_train_top_10)
# Out:
#                          q212813                          q416235  \
# index
# 31844                   Centrist                              Yes
# 21628                      Other  Can't answer without a subtitle
# 51271                      Other  Can't answer without a subtitle
# 12228        Liberal / Left-wing  Can't answer without a subtitle
# 57902  Conservative / Right-wing                               No
# ...                          ...                              ...
# 26463                   Centrist                              Yes
# 33094        Liberal / Left-wing                              Yes
# 59462        Liberal / Left-wing  Can't answer without a subtitle
# 27366                      Other                               No
# 60546        Liberal / Left-wing                              Yes
#
#                                         q85419 q358084 q501         q77  \
# index
# 31844  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 21628  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes      Rarely
# 51271  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes   Sometimes
# 12228          Rosé (such as White Zinfindel).     Yes   No       Never
# 57902                      I don't drink wine.     Yes  Yes       Never
# ...                                        ...     ...  ...         ...
# 26463                      I don't drink wine.     Yes   No      Rarely
# 33094  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes  Very often
# 59462  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 27366          Rosé (such as White Zinfindel).     Yes   No   Sometimes
# 60546  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
#
#                     q20930             q29829   q35660  \
# index
# 31844              Average  Whenever possible  Usually
# 21628  Higher than average  Whenever possible  Usually
# 51271  Higher than average             Always  Usually
# 12228        Below average  Whenever possible  Usually
# 57902  Higher than average             Always   Always
# ...                    ...                ...      ...
# 26463              Average             Always  Usually
# 33094      Very, very high             Always    Never
# 59462              Average  Whenever possible  Usually
# 27366  Higher than average             Always  Usually
# 60546      Very, very high  Whenever possible   Always
#
#                                                q80
# index
# 31844                            I never do drugs.
# 21628                            I never do drugs.
# 51271                            I never do drugs.
# 12228                            I never do drugs.
# 57902  I've done drugs in the past, but no longer.
# ...                                            ...
# 26463                            I never do drugs.
# 33094  I've done drugs in the past, but no longer.
# 59462                     I do drugs occasionally.
# 27366  I've done drugs in the past, but no longer.
# 60546                            I never do drugs.
#
# [13570 rows x 10 columns]

# %%
df_train_top_10.shape
# Out:
# (13570, 10)

# %%
one_hot_encoder = OneHotEncoder()
label_encoder = LabelEncoder()
X_top10_train_onehot, y_top10_train_encoded, X_top10_test_onehot, y_top10_test_encoded = preprocessing.encode_train_test_df(one_hot_encoder, label_encoder, df_train_top_10, df_test_top_10)

# %%
# Fitting Random Forest Classification to the Training set
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42, class_weight='balanced')
classifier.fit(X_top10_train_onehot, y_top10_train_encoded)
y_top10_pred = classifier.predict(X_top10_test_onehot)

# %%
y_top10_pred_decoded = label_encoder.inverse_transform(y_top10_pred)
pd.DataFrame((pd.crosstab(df_test_top_10[political_belief], y_top10_pred_decoded, rownames=['Actual Belief'], colnames=['Predicted Belief'], normalize=0)))
# Out:
# Predicted Belief           Centrist  Conservative / Right-wing  \
# Actual Belief
# Centrist                   0.297340                   0.200313
# Conservative / Right-wing  0.235294                   0.315126
# Liberal / Left-wing        0.267477                   0.160334
# Other                      0.239264                   0.186678
#
# Predicted Belief           Liberal / Left-wing     Other
# Actual Belief
# Centrist                              0.267606  0.234742
# Conservative / Right-wing             0.151261  0.298319
# Liberal / Left-wing                   0.362462  0.209726
# Other                                 0.292726  0.281332

# %% [markdown]
# ## 1. Try top 30

# %%
k = 30

# %%
# questions
top_30 = selected_questions[:k]
df_train_top_30 = df_train_top_kmax[top_30]
df_test_top_30 = df_test_top_kmax[top_30]
display(df_train_top_30)
# Out:
#                          q212813                          q416235  \
# index
# 31844                   Centrist                              Yes
# 21628                      Other  Can't answer without a subtitle
# 51271                      Other  Can't answer without a subtitle
# 12228        Liberal / Left-wing  Can't answer without a subtitle
# 57902  Conservative / Right-wing                               No
# ...                          ...                              ...
# 26463                   Centrist                              Yes
# 33094        Liberal / Left-wing                              Yes
# 59462        Liberal / Left-wing  Can't answer without a subtitle
# 27366                      Other                               No
# 60546        Liberal / Left-wing                              Yes
#
#                                         q85419 q358084 q501         q77  \
# index
# 31844  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 21628  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes      Rarely
# 51271  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes   Sometimes
# 12228          Rosé (such as White Zinfindel).     Yes   No       Never
# 57902                      I don't drink wine.     Yes  Yes       Never
# ...                                        ...     ...  ...         ...
# 26463                      I don't drink wine.     Yes   No      Rarely
# 33094  Red (such as Merlot, Cabernet, Shiraz).     Yes  Yes  Very often
# 59462  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
# 27366          Rosé (such as White Zinfindel).     Yes   No   Sometimes
# 60546  Red (such as Merlot, Cabernet, Shiraz).     Yes   No   Sometimes
#
#                     q20930             q29829   q35660  \
# index
# 31844              Average  Whenever possible  Usually
# 21628  Higher than average  Whenever possible  Usually
# 51271  Higher than average             Always  Usually
# 12228        Below average  Whenever possible  Usually
# 57902  Higher than average             Always   Always
# ...                    ...                ...      ...
# 26463              Average             Always  Usually
# 33094      Very, very high             Always    Never
# 59462              Average  Whenever possible  Usually
# 27366  Higher than average             Always  Usually
# 60546      Very, very high  Whenever possible   Always
#
#                                                q80  ...  q442  \
# index                                               ...
# 31844                            I never do drugs.  ...   Bad
# 21628                            I never do drugs.  ...   Bad
# 51271                            I never do drugs.  ...  Good
# 12228                            I never do drugs.  ...   Bad
# 57902  I've done drugs in the past, but no longer.  ...   Bad
# ...                                            ...  ...   ...
# 26463                            I never do drugs.  ...   Bad
# 33094  I've done drugs in the past, but no longer.  ...  Good
# 59462                     I do drugs occasionally.  ...   Bad
# 27366  I've done drugs in the past, but no longer.  ...   Bad
# 60546                            I never do drugs.  ...  Good
#
#                     q40441       q53611       q19874  \
# index
# 31844  Maybe a little bit.       Never.  6-12 months
# 21628                  No.  Frequently.   12+ months
# 51271  Maybe a little bit.      Rarely.   12+ months
# 12228  Maybe a little bit.      Rarely.   12+ months
# 57902                  No.       Never.  6-12 months
# ...                    ...          ...          ...
# 26463                 Yes.       Never.   12+ months
# 33094                 Yes.       Never.   12+ months
# 59462                 Yes.  Frequently.  6-12 months
# 27366                  No.  Frequently.  6-12 months
# 60546  Maybe a little bit.  Frequently.  6-12 months
#
#                               q1062 q158 q80041                          q128  \
# index
# 31844  Usually daily.  I skip some.  Yes    Yes             I have no tattoos
# 21628  Usually daily.  I skip some.   No    Yes             I have no tattoos
# 51271          At least once a day.  Yes    Yes  I have 1 or more BIG tattoos
# 12228          At least once a day.   No     No             I have no tattoos
# 57902          At least once a day.   No    Yes             I have no tattoos
# ...                             ...  ...    ...                           ...
# 26463          At least once a day.   No    Yes             I have no tattoos
# 33094  Usually daily.  I skip some.  Yes     No             I have no tattoos
# 59462          At least once a day.  Yes     No             I have no tattoos
# 27366          At least once a day.  Yes    Yes             I have no tattoos
# 60546          At least once a day.  Yes    Yes             I have no tattoos
#
#       q16713                                  q1707
# index
# 31844     No          Meh. I have my ups and downs.
# 21628    Yes  Cheerful!  I have a positive outlook.
# 51271    Yes  Cheerful!  I have a positive outlook.
# 12228    Yes          Meh. I have my ups and downs.
# 57902    Yes  Cheerful!  I have a positive outlook.
# ...      ...                                    ...
# 26463    Yes  Cheerful!  I have a positive outlook.
# 33094     No  Cheerful!  I have a positive outlook.
# 59462     No  Cheerful!  I have a positive outlook.
# 27366    Yes  Cheerful!  I have a positive outlook.
# 60546    Yes  Cheerful!  I have a positive outlook.
#
# [13570 rows x 30 columns]

# %%
df_train_top_30.shape
# Out:
# (13570, 30)

# %%
one_hot_encoder = OneHotEncoder()
label_encoder = LabelEncoder()
X_top30_train_onehot, y_top30_train_encoded, X_top30_test_onehot, y_top30_test_encoded = preprocessing.encode_train_test_df(one_hot_encoder, label_encoder, df_train_top_30, df_test_top_30)

# %%
# Fitting Random Forest Classification to the Training set
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42, class_weight='balanced')
classifier.fit(X_top30_train_onehot, y_top30_train_encoded)
y_top30_pred = classifier.predict(X_top30_test_onehot)
y_top30_pred_decoded = label_encoder.inverse_transform(y_top30_pred)

# %% [markdown]
# # Evaluation

# %% [markdown]
# 1. Accuracy, Balanced Accuracy

# %%
print('Top 10 accuary: ',accuracy_score(y_top10_test_encoded, y_top10_pred))
print('Top 30 accuary: ',accuracy_score(y_top30_test_encoded, y_top30_pred))

print('Top 10 balanced accuary: ', balanced_accuracy_score(y_top10_test_encoded, y_top10_pred))
print('Top 30 balanced accuary: ', balanced_accuracy_score(y_top30_test_encoded, y_top30_pred))
# Out:
# Top 10 accuary:  0.3188362327534493
# Top 30 accuary:  0.4631073785242951
# Top 10 balanced accuary:  0.314064953595296
# Top 30 balanced accuary:  0.3661152788771038

# %% [markdown]
# 2. Confusion Matrix

# %%
display(pd.DataFrame(pd.crosstab(df_test_top_10[political_belief], 
                        y_top10_pred_decoded,
                        rownames=['Actual Belief'], colnames=['Predicted Belief'], normalize=0)).style.set_caption('Top 10 questions'))
display(pd.DataFrame(pd.crosstab(df_test_top_30[political_belief], 
                        y_top30_pred_decoded, 
                        rownames=['Actual Belief'], colnames=['Predicted Belief'], normalize=0)).style.set_caption('Top 30 questions'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_71874">
#   <caption>Top 10 questions</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Predicted Belief</th>
#       <th id="T_71874_level0_col0" class="col_heading level0 col0" >Centrist</th>
#       <th id="T_71874_level0_col1" class="col_heading level0 col1" >Conservative / Right-wing</th>
#       <th id="T_71874_level0_col2" class="col_heading level0 col2" >Liberal / Left-wing</th>
#       <th id="T_71874_level0_col3" class="col_heading level0 col3" >Other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Belief</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71874_level0_row0" class="row_heading level0 row0" >Centrist</th>
#       <td id="T_71874_row0_col0" class="data row0 col0" >0.297340</td>
#       <td id="T_71874_row0_col1" class="data row0 col1" >0.200313</td>
#       <td id="T_71874_row0_col2" class="data row0 col2" >0.267606</td>
#       <td id="T_71874_row0_col3" class="data row0 col3" >0.234742</td>
#     </tr>
#     <tr>
#       <th id="T_71874_level0_row1" class="row_heading level0 row1" >Conservative / Right-wing</th>
#       <td id="T_71874_row1_col0" class="data row1 col0" >0.235294</td>
#       <td id="T_71874_row1_col1" class="data row1 col1" >0.315126</td>
#       <td id="T_71874_row1_col2" class="data row1 col2" >0.151261</td>
#       <td id="T_71874_row1_col3" class="data row1 col3" >0.298319</td>
#     </tr>
#     <tr>
#       <th id="T_71874_level0_row2" class="row_heading level0 row2" >Liberal / Left-wing</th>
#       <td id="T_71874_row2_col0" class="data row2 col0" >0.267477</td>
#       <td id="T_71874_row2_col1" class="data row2 col1" >0.160334</td>
#       <td id="T_71874_row2_col2" class="data row2 col2" >0.362462</td>
#       <td id="T_71874_row2_col3" class="data row2 col3" >0.209726</td>
#     </tr>
#     <tr>
#       <th id="T_71874_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_71874_row3_col0" class="data row3 col0" >0.239264</td>
#       <td id="T_71874_row3_col1" class="data row3 col1" >0.186678</td>
#       <td id="T_71874_row3_col2" class="data row3 col2" >0.292726</td>
#       <td id="T_71874_row3_col3" class="data row3 col3" >0.281332</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3a447">
#   <caption>Top 30 questions</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Predicted Belief</th>
#       <th id="T_3a447_level0_col0" class="col_heading level0 col0" >Centrist</th>
#       <th id="T_3a447_level0_col1" class="col_heading level0 col1" >Conservative / Right-wing</th>
#       <th id="T_3a447_level0_col2" class="col_heading level0 col2" >Liberal / Left-wing</th>
#       <th id="T_3a447_level0_col3" class="col_heading level0 col3" >Other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Belief</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a447_level0_row0" class="row_heading level0 row0" >Centrist</th>
#       <td id="T_3a447_row0_col0" class="data row0 col0" >0.154930</td>
#       <td id="T_3a447_row0_col1" class="data row0 col1" >0.014085</td>
#       <td id="T_3a447_row0_col2" class="data row0 col2" >0.483568</td>
#       <td id="T_3a447_row0_col3" class="data row0 col3" >0.347418</td>
#     </tr>
#     <tr>
#       <th id="T_3a447_level0_row1" class="row_heading level0 row1" >Conservative / Right-wing</th>
#       <td id="T_3a447_row1_col0" class="data row1 col0" >0.151261</td>
#       <td id="T_3a447_row1_col1" class="data row1 col1" >0.079832</td>
#       <td id="T_3a447_row1_col2" class="data row1 col2" >0.436975</td>
#       <td id="T_3a447_row1_col3" class="data row1 col3" >0.331933</td>
#     </tr>
#     <tr>
#       <th id="T_3a447_level0_row2" class="row_heading level0 row2" >Liberal / Left-wing</th>
#       <td id="T_3a447_row2_col0" class="data row2 col0" >0.098024</td>
#       <td id="T_3a447_row2_col1" class="data row2 col1" >0.012918</td>
#       <td id="T_3a447_row2_col2" class="data row2 col2" >0.727964</td>
#       <td id="T_3a447_row2_col3" class="data row2 col3" >0.161094</td>
#     </tr>
#     <tr>
#       <th id="T_3a447_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_3a447_row3_col0" class="data row3 col0" >0.079755</td>
#       <td id="T_3a447_row3_col1" class="data row3 col1" >0.011394</td>
#       <td id="T_3a447_row3_col2" class="data row3 col2" >0.369851</td>
#       <td id="T_3a447_row3_col3" class="data row3 col3" >0.539001</td>
#     </tr>
#   </tbody>
# </table>
