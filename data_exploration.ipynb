# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cognitive ability test questions

# %%
# cognitive ability test questions
test_items = pd.read_csv('data/test_items.csv')
print(test_items.columns)
print(test_items.shape)

display(test_items)
# Out:
# Index(['Unnamed: 0', 'ID', 'text', 'option_1', 'option_2', 'option_3',
#        'option_4', 'option_correct'],
#       dtype='object')
# (28, 8)
#    Unnamed: 0      ID                                               text  \
# 0        q178     178                                   Which is bigger?
# 1        q255     255                STALE is to STEAL as 89475 is to...
# 2       q1201    1201   What is next in this series? 1, 4, 10, 19, 31, _
# 3      q14835   14835  If you turn a left-handed glove inside out, it...
# 4       q8672    8672  In the line 'Wherefore art thou Romeo?' what d...
# 5     q438128  438128  In a lake, there is a patch of lily pads. Ever...
# 6     q438126  438126  lf it takes 5 machines 5 minutes to make 5 wid...
# 7     q438117  438117  A bat and a ball cost $1.10.\nThe bat costs on...
# 8     q339289  339289  Sixteen hours are to one day as twenty days ar...
# 9     q273897  273897  __________ taking __________ kids to the bathr...
# 10     q76851   76851                                            2+2*-1=
# 11    q190850  190850                   What is the square root of nine?
# 12    q121178  121178                          x * 0.5 = y , y / 0.5 = z
# 13    q217116  217116                                   1,1,2,3,5,8,___?
# 14    q171475  171475  A die is rolled and a coin is tossed at the sa...
# 15    q173005  173005                    What comes next: 25,24,22,19,15
# 16    q357274  357274   Is the 'light year' a measure of time or length?
# 17    q257302  257302             Can you identify the correct sentence?
# 18    q156459  156459         Stockholm is the capital of which country?
# 19     q18154   18154                 How many fortnights are in a year?
# 20     q12625   12625  Half of all policemen are thieves and half of ...
# 21       q477     477                                   Which is longer?
# 22       q256     256  When birds stand on power lines and don't get ...
# 23     q43639   43639                                    Etymology is...
# 24       q267     267  If some men are doctors and some doctors are t...
# 25     q18698   18698          A little grade 10 science. Ideal Gas Law?
# 26       q511     511  If you flipped three pennies, what would be th...
# 27     q57844   57844   Which is the day before the day after yesterday?
#
#                                      option_1  \
# 0                                   The earth
# 1                                       89457
# 2                                          36
# 3                             On my left hand
# 4                                         Why
# 5                                     24 days
# 6                                   5 minutes
# 7                                       $0.10
# 8                                        True
# 9                       They're, their, there
# 10                                          0
# 11                                          9
# 12                                      x = z
# 13                                          7
# 14                                       1/12
# 15                                          9
# 16                          A measure of time
# 17         Your going to the concert tonight.
# 18                                Switzerland
# 19                                         52
# 20                                        Yes
# 21                                     A mile
# 22  Good timing, they only land between calls
# 23                The study of culinary arts.
# 24                                        Yes
# 25                                   PV = nRT
# 26                     I admit, I don't know!
# 27                                 Yesterday.
#
#                                           option_2  \
# 0                                          The sun
# 1                                            98547
# 2                                               48
# 3                                 On my right hand
# 4                                            Where
# 5                                          25 days
# 6                                       10 minutes
# 7                                            $1.00
# 8                                            False
# 9                            There, they're, their
# 10                                              -4
# 11                                               3
# 12                                           x < z
# 13                                              11
# 14                                             2/3
# 15                                              10
# 16                             A measure of length
# 17          You're not going to eat that, are you?
# 18                                          Sweden
# 19                                              14
# 20                                              No
# 21                                     A kilometer
# 22  Body materials that are insulated from current
# 23                           The study of insects.
# 24                                              No
# 25                                     G + V = 1/T
# 26                                          1 in 3
# 27                                          Today.
#
#                                        option_3  \
# 0                                           NaN
# 1                                         89754
# 2                                            46
# 3                                           NaN
# 4                                           How
# 5                                       47 days
# 6                                    50 minutes
# 7                                         $0.05
# 8                 Who took the time to do this?
# 9                         They're, there, their
# 10                                            4
# 11                                            1
# 12                                        x > z
# 13                                           13
# 14                                          1/3
# 15                                           11
# 16                                          NaN
# 17                                       Unsure
# 18                                       Canada
# 19                                           26
# 20                                          NaN
# 21                                I don't know!
# 22  Not touching anything else at the same time
# 23           The study of the origins of words.
# 24                                          NaN
# 25                                       y=mx+b
# 26                                       1 in 4
# 27                                    Tomorrow.
#
#                                          option_4  option_correct
# 0                                             NaN               2
# 1                                           89547               4
# 2                         Don't know / don't care               3
# 3                                             NaN               2
# 4                                Who cares / wtf?               1
# 5                                         48 days               3
# 6                                     100 minutes               1
# 7                                           $0.15               3
# 8                                             NaN               1
# 9                           Their, they're, there               1
# 10                                      Who cares               1
# 11                                             81               2
# 12                                   I like cats!               1
# 13                                             16               3
# 14          I wish the answer was pie? Is it pie?               1
# 15                                             12               2
# 16                                            NaN               2
# 17                                            NaN               2
# 18                                         Jordan               2
# 19                                            365               3
# 20                                            NaN               2
# 21                                            NaN               1
# 22  They do get hurt, they just express it poorly               3
# 23                                  I don't know.               3
# 24                                            NaN               2
# 25          Not sure / wish I could skip this one               1
# 26                                         1 in 8               3
# 27                                            NaN               1

# %% [markdown]
# ### Question Data

# %%
question_data = pd.read_csv('data/question_data.csv', sep=';')
question_data.set_index('Unnamed: 0')
print(question_data.shape)
print(question_data.columns)
display(question_data)
# Out:
# (2620, 10)
# Index(['Unnamed: 0', 'text', 'option_1', 'option_2', 'option_3', 'option_4',
#        'N', 'Type', 'Order', 'Keywords'],
#       dtype='object')
#        Unnamed: 0                                               text  \
# 0              q2                                   Breast implants?
# 1             q11  How does the idea of being slapped hard in the...
# 2             q12  Divide your age by 2.  Have you had sex with a...
# 3             q13  Is a girl who's slept with 100 guys a bad person?
# 4             q14  Is a guy who's slept with 100 girls a bad person?
# ...           ...                                                ...
# 2615   lf_max_age                                   Max age of match
# 2616       lf_for                                  Looking for match
# 2617  lf_location                                  Location of match
# 2618   lf_min_age                                   Min age of match
# 2619    lf_single                                    Status of match
#
#                      option_1                 option_2   option_3  \
# 0     more cool than pathetic  more pathetic than cool        NaN
# 1                   Horrified                  Aroused  Nostalgic
# 2                         Yes                       No        NaN
# 3                         Yes                       No        NaN
# 4                         Yes                       No        NaN
# ...                       ...                      ...        ...
# 2615                      NaN                      NaN        NaN
# 2616                      NaN                      NaN        NaN
# 2617                      NaN                      NaN        NaN
# 2618                      NaN                      NaN        NaN
# 2619                      NaN                      NaN        NaN
#
#          option_4      N Type Order                           Keywords
# 0             NaN  24839    N   NaN  sex/intimacy; preference; opinion
# 1     Indifferent  28860    N   NaN                       sex/intimacy
# 2             NaN  22496    O   NaN                       sex/intimacy
# 3             NaN  32581    O   NaN                       sex/intimacy
# 4             NaN  31127    O   NaN                       sex/intimacy
# ...           ...    ...  ...   ...                                ...
# 2615          NaN  66365  NaN   NaN                                NaN
# 2616          NaN  66365  NaN   NaN                                NaN
# 2617          NaN  66365  NaN   NaN                                NaN
# 2618          NaN  66365  NaN   NaN                                NaN
# 2619          NaN  66365  NaN   NaN                                NaN
#
# [2620 rows x 10 columns]

# %% [markdown]
# ### Data

# %%
data = pd.read_parquet('data/parsed_data_public.parquet', engine='fastparquet')
print(data.shape)
display(data)
# TODO: Frage: Was sagt Unnamed: 0 hier?
# Out:
# (68371, 2626)
#        Unnamed: 0    q2        q11   q12   q13   q14   q16   q17   q18   q20  \
# 0               1  None  Horrified  None  None  None  None    No  None  None
# 1               2  None       None  None  None  None  None  None  None  None
# 2               3  None       None  None    No    No  None    No  None  None
# 3               4  None       None  None  None  None  None  None  None  None
# 4               5  None       None  None  None  None  None  None  None  None
# ...           ...   ...        ...   ...   ...   ...   ...   ...   ...   ...
# 68366       68367  None       None  None  None  None  None  None  None  None
# 68367       68368  None       None  None  None  None  None  None  None  None
# 68368       68369  None       None  None  None  None  None  None  None  None
# 68369       68370  None       None  None  None  None  None  None  None  None
# 68370       68371  None       None  None  None  None  None  None  None  None
#
#        ... q86615 q86699 q363047        CA gender_orientation gender   race  \
# 0      ...   None   None    None  0.763080      Hetero_female  Woman  White
# 1      ...   None   None    None       NaN        Hetero_male    Man   None
# 2      ...   None   None    None  0.661309      Hetero_female  Woman   None
# 3      ...   None   None    None       NaN      Hetero_female  Woman  White
# 4      ...   None   None    None  0.875424    Bisexual_female  Woman   None
# ...    ...    ...    ...     ...       ...                ...    ...    ...
# 68366  ...   None   None    None       NaN        Hetero_male    Man  White
# 68367  ...   None   None    None       NaN      Hetero_female  Woman   None
# 68368  ...   None   None    None       NaN        Hetero_male    Man   None
# 68369  ...   None   None    None       NaN      Hetero_female  Woman  White
# 68370  ...   None   None    None       NaN        Hetero_male    Man  Other
#
#       gender2 gender2_num CA_items
# 0       Woman         0.0        4
# 1         Man         1.0        0
# 2       Woman         0.0        7
# 3       Woman         0.0        0
# 4       Woman         0.0        3
# ...       ...         ...      ...
# 68366     Man         1.0        0
# 68367   Woman         0.0        0
# 68368     Man         1.0        0
# 68369   Woman         0.0        0
# 68370     Man         1.0        0
#
# [68371 rows x 2626 columns]

# %% [markdown]
# ## Exploration

# %% [markdown]
# List of keywords

# %%
keys = set(question_data.Keywords)
print(len(keys))
print(keys)
# Out:
# 62
# {'politics; descriptive; preference', 'sex/intimacy; preference', 'opinion; cognitive', 'opinion', 'politics; cognitive', nan, 'sex/intimacy; preference; descriptive', 'descriptive; technology', 'politics; sex/intimacy; preference', 'politics; opinion; cognitive', 'sex/intimacy; religion/superstition; preference', 'sex/intimacy; BDSM', 'politics; religion/superstition', 'politics; opinion; sex/intimacy', 'sex/intimacy; religion/superstition', 'politics; preference; opinion; sex/intimacy', 'descriptive', 'politics; descriptive', 'descriptive; preference', 'religion/superstition; opinion', 'preference; descriptive; technology', 'preference; descriptive; opinion', 'preference; descriptive; politics', 'politics; opinion', 'politics; preference; opinion', 'preference; technology', 'descriptive; opinion', 'sex/intimacy; preference; opinion', 'religion/superstition', 'religion/superstition; opinion; cognitive', 'sex/intimacy; descriptive; BDSM', 'religion/superstition; preference', 'descriptive; cognitive', 'politics; religion/superstition; descriptive', 'preference; cognitive', 'preference; descriptive', 'politics; sex/intimacy; descriptive', 'politics; sex/intimacy; religion/superstition; opinion', 'sex/intimacy; religion/superstition; descriptive', 'descriptive; preference; opinion', 'preference; opinion', 'politics; religion/superstition; opinion', 'politics; opinion; preference', 'religion/superstition; descriptive', 'descriptive; BDSM', 'opinion; technology', 'politics; preference; descriptive', 'cognitive', 'preference; descriptive; cognitive', 'sex/intimacy; religion/superstition; opinion', 'politics; religion/superstition; preference', 'preference', 'politics; preference', 'politics; sex/intimacy; religion/superstition ', 'politics; opinion; technology', 'opinion; descriptive', 'religion/superstition; descriptive; preference', 'politics', 'sex/intimacy; opinion', 'sex/intimacy; descriptive', 'sex/intimacy; preference; BDSM', 'sex/intimacy'}

# %% [markdown]
# Add column with number of answers per question

# %%
# per question count number of times the question is answered
n_answers_per_question = data.notnull().sum(axis=0)[1:]
question_data = question_data.join(n_answers_per_question.to_frame('n_answers'))

# %%
# find political questions
political_questions = question_data[question_data.Keywords.str.contains('politics', na=False)]
print(f'number of questions involving politcs: {political_questions.shape[0]}')
display(political_questions)
# Out:
# number of questions involving politcs: 270
#                                                          text  \
# Unnamed: 0
# q71                       Is interracial marriage a bad idea?
# q166                      Politically, which way do you lean?
# q167                                          Do you recycle?
# q168        The life of one of your fellow citizens is mor...
# q169                   Should the death penalty be abolished?
# ...                                                       ...
# q91207      Homosexuality is illegal in many countries, wi...
# q140080                 Is abortion okay if a woman is raped?
# q179268                   Are you either vegetarian or vegan?
# q212813          Which best describes your political beliefs?
# q227646             How do you describe yourself politically?
#
#                                                  option_1  \
# Unnamed: 0
# q71                                                   Yes
# q166                  To the right (republican in the US)
# q167                                        Almost always
# q168                                                 True
# q169                                                  Yes
# ...                                                   ...
# q91207      YES- homosexuality should be against the law.
# q140080                                               Yes
# q179268                                               Yes
# q212813                               Liberal / Left-wing
# q227646                                   As a Republican
#
#                                       option_2  \
# Unnamed: 0
# q71                                         No
# q166          To the left (democrat in the US)
# q167                                 Sometimes
# q168                                     False
# q169                                        No
# ...                                        ...
# q91207      NO- homosexuality should be legal.
# q140080                                     No
# q179268                                     No
# q212813                               Centrist
# q227646                          As a Democrat
#
#                                       option_3  \
# Unnamed: 0
# q71                                        NaN
# q166              To the middle / I don't know
# q167                      Rarely or not at all
# q168                                       NaN
# q169                                       NaN
# ...                                        ...
# q91207                            I'm Not Sure
# q140080                         I can't decide
# q179268                                    NaN
# q212813              Conservative / Right-wing
# q227646     As a an Independent/Something Else
#
#                                     option_4      N Type    Order  \
# Unnamed: 0
# q71                                      NaN  32492    O      NaN
# q166                                     NaN  11714    O  1, 3, 2
# q167                                     NaN  24586    O      NaN
# q168                                     NaN  22138    O      NaN
# q169                                     NaN  16884    O      NaN
# ...                                      ...    ...  ...      ...
# q91207                                   NaN    174    O  2, 3, 1
# q140080                                  NaN    306    O  2, 3, 1
# q179268                                  NaN  54202    O      NaN
# q212813                                Other  45107    M      [4]
# q227646     None of these / I'm not American  12240    N      NaN
#
#                                    Keywords  n_answers
# Unnamed: 0
# q71                                politics    32492.0
# q166                               politics    11714.0
# q167                               politics    24586.0
# q168                               politics    22138.0
# q169                               politics    16884.0
# ...                                     ...        ...
# q91207      politics; religion/superstition      174.0
# q140080     politics; religion/superstition      306.0
# q179268               politics; descriptive    54202.0
# q212813               politics; descriptive    45107.0
# q227646               politics; descriptive    12240.0
#
# [270 rows x 10 columns]

# %%
# sorted political questions
sorted_p_questions = political_questions.sort_values(by=['n_answers'], ascending=False)
display(sorted_p_questions.head())
# Out:
#                                                          text  \
# Unnamed: 0
# q34113      How do you feel about government-subsidized fo...
# q179268                   Are you either vegetarian or vegan?
# q403                        Do you enjoy discussing politics?
# q175           Should burning your country's flag be illegal?
# q212813          Which best describes your political beliefs?
#
#                        option_1                        option_2  \
# Unnamed: 0
# q34113               No problem  It's okay, if it is not abused
# q179268                     Yes                              No
# q403                        Yes                              No
# q175                        Yes                              No
# q212813     Liberal / Left-wing                        Centrist
#
#                                   option_3           option_4      N Type  \
# Unnamed: 0
# q34113      Okay for short amounts of time  Never - Get a job  31769    O
# q179268                                NaN                NaN  54202    O
# q403                                   NaN                NaN  52369    O
# q175                                   NaN                NaN  45720    O
# q212813          Conservative / Right-wing              Other  45107    M
#
#            Order                           Keywords  n_answers
# Unnamed: 0
# q34113       NaN                           politics    68371.0
# q179268      NaN              politics; descriptive    54202.0
# q403         NaN  politics; preference; descriptive    52369.0
# q175         NaN                           politics    45720.0
# q212813      [4]              politics; descriptive    45107.0
