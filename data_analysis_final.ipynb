# %% [markdown]
# # Import packages and aux functions

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import ast
from utils import preprocessing, plotting
sns.set(style='darkgrid')
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.naive_bayes import CategoricalNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, balanced_accuracy_score
from sklearn.model_selection import (cross_validate, cross_val_predict,cross_val_score, train_test_split, StratifiedKFold, 
                                    permutation_test_score, GridSearchCV, RandomizedSearchCV, RandomizedSearchCV)
from pprint import pprint
from joblib import dump, load
import joblib

# %%
def get_sorted_feat_importance(importance, feature_names):
    feature_importance = np.array(importance)
    feature_names = np.array(feature_names)

    #Create a DataFrame using a Dictionary
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)

    #Sort the DataFrame in order decreasing feature importance
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_df['cum_sum_fi']=fi_df['feature_importance'].cumsum()
    return fi_df

# %% [markdown]
# # Content
# ### 1. Load Data
# - Questions Data
# - Feature Data
# ### 2. Data Preprocessing
# - Hyperparametertuning: Optimize Ratio: (Nr of feature)/(Train set size)
# - Downsampling the dataset with chosen features
# - Visualization of the feature distributions
# - Feature Encoding: Label Encoding
# ### 3. Baseline Model: Naive Bayes
# ### 4. Random Forest Model
# - Hyperparametertuning with RandomSearch
# - Feature importance
# ### 5. Evaluation
# - Permutation Test
# - Cross-Validation

# %% [markdown]
# # Load Data

# %%
questions = pd.read_csv('data/questions_preprocessed.csv', sep=';', index_col=0)
descriptive_questions = [i for i in questions.index if i.startswith('dq')]
questions.loc[descriptive_questions, 'Order'] = questions.loc[descriptive_questions, 'Order'].apply(lambda row: ast.literal_eval(row))

# drop descriptive questions that reference politics 
for i in descriptive_questions:
    if any(keyword in questions.loc[i, 'text'] for keyword in ['politics', 'political', 'politician']):
            descriptive_questions.remove(i)
            
display(questions.head())
# Out:
#                                                    text  \
# q_id
# q2                                     Breast implants?
# q11   How does the idea of being slapped hard in the...
# q12   Divide your age by 2.  Have you had sex with a...
# q13   Is a girl who's slept with 100 guys a bad person?
# q14   Is a guy who's slept with 100 girls a bad person?
#
#                      option_1                 option_2   option_3  \
# q_id
# q2    more cool than pathetic  more pathetic than cool        NaN
# q11                 Horrified                  Aroused  Nostalgic
# q12                       Yes                       No        NaN
# q13                       Yes                       No        NaN
# q14                       Yes                       No        NaN
#
#          option_4      N Type Order                           Keywords
# q_id
# q2            NaN  24839    N   NaN  sex/intimacy; preference; opinion
# q11   Indifferent  28860    N   NaN                       sex/intimacy
# q12           NaN  22496    O   NaN                       sex/intimacy
# q13           NaN  32581    O   NaN                       sex/intimacy
# q14           NaN  31127    O   NaN                       sex/intimacy

# %%
data = pd.read_parquet('data/train.parquet')
# per question count number of times the question is answered
n_answers_per_question = data.loc[:, descriptive_questions].count(axis=0)
sorted_questions = n_answers_per_question.sort_values(ascending=False).index

question_data = questions.join(n_answers_per_question.to_frame('n_answers')) 
display(questions.loc[sorted_questions[:10]][['text']])

features_df = data[descriptive_questions]
print('Nr of rows, nr of descriptive questions', features_df.shape)
# Out:
#                                                     text
# dq823  Do you like watching foreign movies with subti...
# dq789  Which type of wine would you prefer to drink o...
# dq109  Have you smoked a cigarette in the last 6 months?
# dq821   Do you enjoy intense intellectual conversations?
# dq8                 How frequently do you drink alcohol?
# dq305                         Rate your self-confidence:
# dq373               How often do you keep your promises?
# dq420         How often are you open with your feelings?
# dq10   What's your deal with harder drugs (stuff beyo...
# dq141                      Are you happy with your life?
# Nr of rows, nr of descriptive questions (40596, 828)

# %%
# Get relative frequencies
freqs = data['political_belief'].value_counts(normalize=True)*100
title = questions.loc['q212813', 'text']
freqs = freqs.rename(index = {'Liberal / Left-wing': 'Liberal/Left-wing', 'Conservative / Right-wing': 'Conservative/Right-wing'})
freqs
# Out:
# Liberal/Left-wing          44.383683
# Other                      31.229678
# Centrist                   17.504188
# Conservative/Right-wing     6.882451
# Name: political_belief, dtype: float64

# %%
sns.set(font_scale=1)
plt.figure(figsize=(12, 6))
sns.set_style("white")
sns.set_style("ticks")
g = sns.barplot(x=freqs.index, y=freqs.values,
            order=['Liberal/Left-wing', 'Centrist', 'Conservative/Right-wing', 'Other'],
            palette={'Liberal/Left-wing': '#5770db', 'Centrist': '#db57b2', 'Conservative/Right-wing': '#ba2832', 'Other': '#fdbf6f'},
            width=0.7
            ).set(title=title, ylabel='percentage (%)', xticklabels=['Liberal', 'Centrist', 'Conservative', 'Other'])
sns.despine(top=True, right=True)
plt.savefig("data/images/Political_Belief_Distribution.png")
plt.show()

# %%
df_trn, df_val = train_test_split(data[descriptive_questions + ['political_belief', 'gender', 'd_age']], test_size=0.1, random_state=1)
df_val = df_val[descriptive_questions+['political_belief']]

# %% [markdown]
# # Data preprocessing
# To keep the train set reasonably big, we compute, how many questions we can include, s.t. that the nr. of subjects who answered these questions is at least 8.000.

# %%
K=200
subset_size_topk = [features_df.loc[:, sorted_questions[:k]].dropna().shape[0] for k in range(1, K)]

# %%
# biggest k with >8.000 to 25.000 subjects who answered ALL k questions
min_train_size = np.arange(8, 25)*1000
n_most_answered = [next(x[0] for x in enumerate(subset_size_topk) if x[1] < min_set_size) for min_set_size in min_train_size]
n_most_answered
# Out:
# [72, 62, 55, 49, 43, 38, 35, 31, 26, 25, 23, 21, 19, 18, 18, 17, 15]

# %%
print(f'Shape of validation set before: {df_val.shape}')
top_questions = sorted_questions[:np.max(n_most_answered)].to_list()
df_val_topq = df_val[top_questions+['political_belief']].dropna() 
print(f'Shape of validation set after selecting the top {np.max(n_most_answered)} questions: {df_val_topq.shape}')

X_val_topq = df_val_topq[top_questions]
y_val = df_val_topq[['political_belief']]
# Out:
# Shape of validation set before: (4060, 829)
# Shape of validation set after selecting the top 72 questions: (805, 73)

# %%
for n, min_size in zip(n_most_answered[:2], min_train_size):
    sns.set_style("white")
    sns.set_style("ticks")
    sns.set
    g = sns.lineplot(x = range(1,K), y = subset_size_topk, linewidth=1)
    g.axhline(y=min_size, color='red', linewidth=0.5)
    g.axvline(x=n, color='red', linewidth=0.5)

    plt.xlim(0, 200)
    plt.ylim(0)
    sns.despine()
    #plt.ylim(0,len(features_df))
    g.set(xlabel ="Cardinality of set of most answered questions", ylabel = "Nr of subjects who answered the questions")
    #title ='Nr of subjects who answered the same k most anwered questions '
    #plt.figtext(0.5, -0.1, 'Grouping most answered questions into a set, comparing the number of questions in the set to the number of subjects who answered all questions in the set', wrap=True, horizontalalignment='center', fontsize=12)
    plt.title(f'minimum train size before downsampling: {min_size}')
    plt.show()

# %% [markdown]
# ## HPO: Optimize Ratio: (Nr of feature)/(Train set size)

# %%
val_scores = []

for n in n_most_answered:
    top_questions = sorted_questions[:n].to_list()
    filter_by = top_questions + ['political_belief']
    downsampled_df = df_trn[filter_by].dropna()
    n_conservative = downsampled_df.groupby('political_belief').count().iloc[1, 0]
    downsampled_df = downsampled_df.groupby('political_belief', group_keys=False).apply(lambda x: x.sample(n=n_conservative, random_state=1))


    # split into features and target
    features_df_downsampled = downsampled_df[top_questions]
    target = downsampled_df.loc[features_df_downsampled.index][['political_belief']]

    # encode train and validation set
    feature_encoder = OrdinalEncoder()
    target_encoder = LabelEncoder()
    # train set
    X_train_encoded = feature_encoder.fit_transform(features_df_downsampled)
    y_train_encoded = target_encoder.fit_transform(target.values.ravel())
    # val set
    X_val_encoded = feature_encoder.transform(X_val_topq[top_questions])
    y_val_encoded = target_encoder.transform(y_val.values.ravel())

    # Naive Bayes Hyper parameter Tuning
    nb = CategoricalNB(fit_prior=False).fit(X_train_encoded, y_train_encoded)
    preds = nb.predict(X_val_encoded)
    val_scores.append(balanced_accuracy_score(y_val_encoded, preds))

best_nr_of_questions = n_most_answered[np.argmax(val_scores)]
print(f'Best balanced accuracy on the validation set obtained with {best_nr_of_questions} number of answered questions')
# Out:
# Best balanced accuracy on the validation set obtained with 62 number of answered questions

# %%
sns.set_style("white")
sns.set_style("ticks")
g = sns.lineplot(x = n_most_answered, y = val_scores, linewidth=1)
g.axhline(y=np.max(val_scores), color='red', linewidth=0.5)
g.axvline(x=best_nr_of_questions, color='red', linewidth=0.5)
sns.despine()
g.set(ylabel ='Balanced Accuracy Score', xlabel ='Nr of questions as features', title='Evaluation on validation set')
plt.show()

# %% [markdown]
# ## Downsampling the dataset with chosen features

# %%
top_questions = sorted_questions[:best_nr_of_questions].to_list()
filter_by = top_questions + ['political_belief', 'd_age', 'gender']
downsampled_df = data[filter_by].dropna()
n_conservative = downsampled_df.groupby('political_belief').count().iloc[1, 0]
downsampled_df = downsampled_df.groupby('political_belief', group_keys=False).apply(lambda x: x.sample(n=n_conservative, random_state=1))
display(downsampled_df.head())
# Out:
#                                  dq823  \
# index
# 29313                              Yes
# 34130                              Yes
# 32212                              Yes
# 60681  Can't answer without a subtitle
# 22553                              Yes
#
#                                          dq789 dq109 dq821         dq8  \
# index
# 29313    White (such as Chardonnay, Riesling).    No   Yes   Sometimes
# 34130  Red (such as Merlot, Cabernet, Shiraz).    No   Yes      Rarely
# 32212          Rosé (such as White Zinfindel).    No   Yes      Rarely
# 60681    White (such as Chardonnay, Riesling).    No   Yes  Very often
# 22553          Rosé (such as White Zinfindel).    No   Yes   Sometimes
#
#                      dq305              dq373    dq420  \
# index
# 29313              Average  Whenever possible   Always
# 34130  Higher than average             Always  Usually
# 32212  Higher than average  Whenever possible   Always
# 60681              Average  Whenever possible  Usually
# 22553  Higher than average  Whenever possible   Always
#
#                                               dq10 dq141  ...       dq158  \
# index                                                     ...
# 29313  I've done drugs in the past, but no longer.   Yes  ...     Average
# 34130                            I never do drugs.   Yes  ...     Slender
# 32212                            I never do drugs.   Yes  ...    Athletic
# 60681  I've done drugs in the past, but no longer.    No  ...  Voluptuous
# 22553  I've done drugs in the past, but no longer.   Yes  ...    Athletic
#
#               dq251                        dq257                        dq307  \
# index
# 29313  Occasionally       Yes, with a cook book.  Yeah, when I have the time.
# 34130            No       Yes, with a cook book.  Yeah, when I have the time.
# 32212  Occasionally  Yes, I'm a culinary genius.                      Always.
# 60681           Yes       Yes, with a cook book.  Yeah, when I have the time.
# 22553           Yes  Yes, I'm a culinary genius.  Yeah, when I have the time.
#
#            dq256 dq681 dq270 political_belief d_age gender
# index
# 29313  Sometimes   No.   Yes         Centrist  29.0    Man
# 34130        Yes   No.    No         Centrist  37.0    Man
# 32212         No   No.    No         Centrist  31.0    Man
# 60681        Yes   No.    No         Centrist  34.0  Woman
# 22553  Sometimes   No.   Yes         Centrist  37.0    Man
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Visualize of the feature distribution

# %%
def plot_question_density(question: str, data: pd.DataFrame, questions: pd.DataFrame, save:bool=False, x_lim=None, legend:bool=True, font_scale=1.5):
    x,y = question, 'political_belief'
    df1 = ((data.groupby(x)[y].value_counts())/len(data)).rename('percentage').reset_index()
    df1['percentage'] = df1['percentage']*100
    title = questions.loc[question, 'text']
    plt.figure(figsize=(8,20))
    sns.set(font_scale=font_scale)
    sns.set_style("white")
    sns.set_style("ticks")
    if not x_lim:
        x_lim = np.max(df1['percentage'])+2
    g = sns.catplot(x='percentage',y=x,hue=y, kind='bar', data=df1, 
                hue_order= ['Liberal / Left-wing', 'Centrist', 'Conservative / Right-wing', 'Other'], 
                palette={'Liberal / Left-wing': '#5770db', 'Centrist': '#db57b2', 'Conservative / Right-wing': '#ba2832', 'Other': '#fdbf6f'},
                order = questions.loc[question, 'Order'],
                legend=False,
                height = 10, aspect = 1.8,
    
                ).set(xlabel ="percentage (%)", ylabel = "", title=title) 
    #plt.xlim(0,x_lim)
    plt.xticks(np.arange(0, x_lim+1, 2))     
    if legend:
        plt.legend(title="", bbox_to_anchor=(1, 1), loc='upper left', fontsize=40)
    
    if save:
        plt.savefig(f'data/images/{question}.png',bbox_inches='tight')
    sns.despine(right=True, top=True)
    plt.show()

# %%
top2_important = ['dq586', 'dq9']
plot_question_density('dq586', downsampled_df, questions, x_lim=16, save=True, legend=False, font_scale=4)
plot_question_density('dq9', downsampled_df, questions, x_lim=16, save=True, font_scale=4)

# %%
top_questions
# Out:
# ['dq823',
#  'dq789',
#  'dq109',
#  'dq821',
#  'dq8',
#  'dq305',
#  'dq373',
#  'dq420',
#  'dq10',
#  'dq141',
#  'dq9',
#  'dq0',
#  'dq268',
#  'dq198',
#  'dq331',
#  'dq500',
#  'dq296',
#  'dq299',
#  'dq824',
#  'dq95',
#  'dq475',
#  'dq581',
#  'dq294',
#  'dq118',
#  'dq40',
#  'dq725',
#  'dq34',
#  'dq234',
#  'dq136',
#  'dq173',
#  'dq64',
#  'dq117',
#  'dq516',
#  'dq337',
#  'dq579',
#  'dq237',
#  'dq426',
#  'dq657',
#  'dq820',
#  'dq391',
#  'dq348',
#  'dq359',
#  'dq327',
#  'dq379',
#  'dq354',
#  'dq759',
#  'dq470',
#  'dq11',
#  'dq175',
#  'dq60',
#  'dq650',
#  'dq23',
#  'dq586',
#  'dq679',
#  'dq663',
#  'dq158',
#  'dq251',
#  'dq257',
#  'dq307',
#  'dq256',
#  'dq681',
#  'dq270']

# %%
# split into features and target
features_df_topq = downsampled_df[top_questions]
target = downsampled_df.loc[features_df_topq.index][['political_belief']]

# %%
feature_encoder = OrdinalEncoder()
target_encoder = LabelEncoder()
X_train_encoded = feature_encoder.fit_transform(features_df_topq)
y_train_encoded = target_encoder.fit_transform(target.values.ravel())

# %%
import pickle

# %%
pickle.dump(feature_encoder, open('models/feature_encoder.pkl', 'wb'))
pickle.dump(target_encoder, open('models/target_encoder.pkl', 'wb'))

# %%
print('Size of final downsampled trainset')
X_train_encoded.shape
# Out:
# Size of final downsampled trainset
# (2980, 62)

# %% [markdown]
# # Baseline Model: Naive Bayes

# %%
nb = CategoricalNB(fit_prior=False).fit(X_train_encoded, y_train_encoded)
scores = cross_val_score(nb, X_train_encoded, y_train_encoded, cv=3, scoring='balanced_accuracy')
print(f"balanced accuracy with mean: {scores.mean()} a standard deviation of {scores.std()}")
# Out:
# balanced accuracy with mean: 0.42283920628751565 a standard deviation of 0.017220946299570595

# %%
# Save model
dump(nb, 'models/nb_downsampled_trn_set.joblib')
# Out:
# ['models/nb_downsampled_trn_set.joblib']

# %% [markdown]
# # Random Forest Classifier
# ## Hyperparameter Tuning
# HPT using Random Search with downsampled K-fold crossvalidation \
# Chosen scoring metrics: balanced accuracy (average of recall obtained on each class)

# %%
# Choose parameter distributions
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1500, num = 10)]
max_depth = [int(x) for x in np.linspace(10, 110, num = 15)]
min_samples_split = [8, 10, 12, 14, 15, 16, 18]
min_samples_leaf = [1, 2, 3, 4]
bootstrap = [True, False]
param_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
              'bootstrap': bootstrap,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               }
pprint(param_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [10, 17, 24, 31, 38, 45, 52, 60, 67, 74, 81, 88, 95, 102, 110],
#  'min_samples_leaf': [1, 2, 3, 4],
#  'min_samples_split': [8, 10, 12, 14, 15, 16, 18],
#  'n_estimators': [200, 344, 488, 633, 777, 922, 1066, 1211, 1355, 1500]}

# %%
rf = RandomForestClassifier(class_weight='balanced', random_state=1)
rf_random = RandomizedSearchCV(estimator = rf,
                             param_distributions = param_grid, 
                             n_iter = 500, 
                             cv = 3, 
                             verbose=2, 
                             random_state=42, 
                             n_jobs = -1, 
                             scoring='balanced_accuracy')
rf_random.fit(X_train_encoded, y_train_encoded)
# Out:
# Fitting 3 folds for each of 500 candidates, totalling 1500 fits
# RandomizedSearchCV(cv=3,
#                    estimator=RandomForestClassifier(class_weight='balanced',
#                                                     random_state=1),
#                    n_iter=500, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 17, 24, 31, 38, 45,
#                                                       52, 60, 67, 74, 81, 88,
#                                                       95, 102, 110],
#                                         'min_samples_leaf': [1, 2, 3, 4],
#                                         'min_samples_split': [8, 10, 12, 14, 15,
#                                                               16, 18],
#                                         'n_estimators': [200, 344, 488, 633,
#                                                          777, 922, 1066, 1211,
#                                                          1355, 1500]},
#                    random_state=42, scoring='balanced_accuracy', verbose=2)

# %%
print('Results of parameter tuning with random search:')
best_random_params = rf_random.best_params_
pprint(best_random_params)
# Out:
# Results of parameter tuning with random search:
# {'bootstrap': True,
#  'max_depth': 88,
#  'min_samples_leaf': 1,
#  'min_samples_split': 14,
#  'n_estimators': 777}

# %%
rf_tuned = rf_random.best_estimator_
scores = cross_val_score(rf_tuned, X_train_encoded, y_train_encoded, cv=5, scoring='balanced_accuracy')
print(f"balanced accuracy with mean: {scores.mean()} a standard deviation of {scores.std()}")
# Out:
# balanced accuracy with mean: 0.4318791946308725 a standard deviation of 0.022823726272660348

# %%
# save model
dump(rf_tuned, 'models/rf_downsampled_trn_set.joblib')
# Out:
# ['models/rf_downsampled_trn_set.joblib']

# %% [markdown]
# ## Visualize feature importance

# %%
fi_df = get_sorted_feat_importance(rf_tuned.feature_importances_, features_df_topq.columns)
print('Top 20 Features sorted by their gini impotance scores ')
for i, row in fi_df[:20].iterrows():
    print(f"Feature {row['feature_names']}: {questions.loc[row['feature_names']].text}: {row['feature_importance']}")
# Out:
# Top 20 Features sorted by their gini impotance scores
# Feature dq586: If you discovered a spider on the wall in your bedroom, which would you do?: 0.03143563607592555
# Feature dq9: What's your relationship with marijuana?: 0.0301292628426395
# Feature dq379: 'Your a bitch!' What bothers you more about the above sentence?: 0.02941868542826218
# Feature dq426: Are you ready to settle down and get married right now?: 0.028493114025724634
# Feature dq268: If you had to name your greatest motivation in life thus far, what would it be?: 0.02792223436856801
# Feature dq823: Do you like watching foreign movies with subtitles?: 0.027095861571939505
# Feature dq824: How do you feel about documentaries?: 0.02564472469579409
# Feature dq348: You're dating someone new. You discover that they have a housemate the same sex as you. This:: 0.02468710751295532
# Feature dq679: How important to you is being with family during holidays?: 0.024576560879917442
# Feature dq251: Do you have a dark and morbid sense of humor?: 0.024544988973562328
# Feature dq789: Which type of wine would you prefer to drink outside of a meal, such as for leisure?: 0.023727924235278537
# Feature dq158: How would you describe your body?: 0.02293591530386874
# Feature dq60: What's the highest level of education you've completed?: 0.02052316899354361
# Feature dq8: How frequently do you drink alcohol?: 0.01957254831751489
# Feature dq657: If it were legal to do so where you live, would you smoke marijuana?: 0.019498688720671585
# Feature dq305: Rate your self-confidence:: 0.01921608156537386
# Feature dq11: How much do you go 'clubbing' (out dancing in bars)?: 0.019100978629534533
# Feature dq391: Are you an adventurous eater? Do you like to try new foods and ethnic cuisines?: 0.018554355952948586
# Feature dq257: Can you cook?: 0.018219146859405254
# Feature dq34: Do you have any tattoos?: 0.018193694878372437

# %%
#Define size of bar plot
plt.figure(figsize=(10,8))
sns.set_style("white")
sns.set_style("ticks")
#Plot Searborn bar chart
g = sns.barplot(y=fi_df['feature_importance'].values, x=np.arange(len(fi_df.index)), color='gray', alpha=0.7)
sns.despine()

g.set_xticklabels(fi_df['feature_names'])
#Add chart labels
g.set_title('Random forest: Sorted feature imporatance (gini)')
g.set(ylabel ='feature impotance', xlabel ='question_ids')
plt.show()

# %%
# first top k question, s.t. Cumultative sum of feature importance is >=.95
cum_sum_top_k = next(x[0] for x in enumerate(fi_df.cum_sum_fi) if x[1] >=0.95)

sns.set_style("white")
sns.set_style("ticks")
g = sns.lineplot(x = np.arange(len(fi_df)), y = fi_df['cum_sum_fi'])
g.axhline(y=fi_df['cum_sum_fi'].iloc[cum_sum_top_k], color='red', linewidth=0.5)
g.axvline(x=cum_sum_top_k, color='red', linewidth=0.5)
sns.despine()
plt.ylim(0)
plt.xlim(0)
g.set(xlabel='number of included features', ylabel='cum. score', title='Cumultative sum of feature importance', xticks=np.arange(len(fi_df), step=2))
plt.show()
# Out:
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=2, min_samples_split=15, n_estimators=633; total time=   4.2s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=3, min_samples_split=15, n_estimators=1500; total time=   9.7s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=2, min_samples_split=16, n_estimators=922; total time=   5.1s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=1, min_samples_split=12, n_estimators=1500; total time=   8.7s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=3, min_samples_split=8, n_estimators=633; total time=   3.9s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=14, n_estimators=1211; total time=   7.7s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=3, min_samples_split=15, n_estimators=777; total time=   4.3s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=3, min_samples_split=12, n_estimators=922; total time=   5.6s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=1, min_samples_split=10, n_estimators=1355; total time=   8.6s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=3, min_samples_split=10, n_estimators=1066; total time=   8.2s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=1, min_samples_split=18, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=1, min_samples_split=10, n_estimators=488; total time=   3.0s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=3, min_samples_split=14, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=14, n_estimators=777; total time=   4.4s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=14, n_estimators=488; total time=   2.8s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=1, min_samples_split=8, n_estimators=488; total time=   3.7s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=18, n_estimators=777; total time=   4.8s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=1, min_samples_split=10, n_estimators=633; total time=   3.8s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=4, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=1, min_samples_split=14, n_estimators=922; total time=   5.2s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=3, min_samples_split=12, n_estimators=1066; total time=   7.1s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=1, min_samples_split=10, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=1, min_samples_split=8, n_estimators=1500; total time=  11.5s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=1, min_samples_split=10, n_estimators=1355; total time=   9.8s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=4, min_samples_split=12, n_estimators=777; total time=   4.4s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=1, min_samples_split=8, n_estimators=488; total time=   3.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=1211; total time=   7.8s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=1, min_samples_split=12, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=3, min_samples_split=8, n_estimators=1211; total time=   7.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=14, n_estimators=633; total time=   2.7s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=3, min_samples_split=16, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=3, min_samples_split=15, n_estimators=1066; total time=   5.9s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=2, min_samples_split=18, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=3, min_samples_split=12, n_estimators=1211; total time=   8.1s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   8.7s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=3, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=4, min_samples_split=14, n_estimators=922; total time=   6.1s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=4, min_samples_split=16, n_estimators=1500; total time=   9.5s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=2, min_samples_split=8, n_estimators=922; total time=   5.7s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=16, n_estimators=1066; total time=   6.6s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   8.7s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=1, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=1, min_samples_split=10, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=2, min_samples_split=10, n_estimators=1355; total time=   8.2s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=2, min_samples_split=14, n_estimators=1500; total time=  10.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=488; total time=   2.9s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=1, min_samples_split=12, n_estimators=1211; total time=   8.3s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=1, min_samples_split=8, n_estimators=1211; total time=   7.6s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=8, n_estimators=777; total time=   5.7s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=8, n_estimators=488; total time=   3.6s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=1, min_samples_split=15, n_estimators=488; total time=   3.2s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=12, n_estimators=1355; total time=   9.1s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=8, n_estimators=1355; total time=  10.0s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=2, min_samples_split=12, n_estimators=777; total time=   4.5s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=3, min_samples_split=12, n_estimators=777; total time=   4.4s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=3, min_samples_split=10, n_estimators=344; total time=   2.5s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=1, min_samples_split=14, n_estimators=344; total time=   2.4s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=2, min_samples_split=12, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=2, min_samples_split=15, n_estimators=633; total time=   4.2s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=3, min_samples_split=15, n_estimators=1500; total time=   9.8s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   2.5s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=2, min_samples_split=10, n_estimators=488; total time=   2.9s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=1, min_samples_split=10, n_estimators=922; total time=   6.7s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=1, min_samples_split=10, n_estimators=1355; total time=   8.2s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=3, min_samples_split=16, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=3, min_samples_split=14, n_estimators=488; total time=   3.2s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=2, min_samples_split=18, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=1355; total time=   8.8s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=4, min_samples_split=12, n_estimators=1355; total time=   7.8s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=3, min_samples_split=16, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   8.6s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=1, min_samples_split=10, n_estimators=1355; total time=  10.0s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=4, min_samples_split=14, n_estimators=1211; total time=   7.7s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=1, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=4, min_samples_split=18, n_estimators=922; total time=   4.9s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=12, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=3, min_samples_split=15, n_estimators=488; total time=   3.2s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=1, min_samples_split=8, n_estimators=1211; total time=   7.7s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=8, n_estimators=777; total time=   5.8s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=8, n_estimators=488; total time=   3.6s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=1, min_samples_split=15, n_estimators=488; total time=   3.3s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=1, min_samples_split=15, n_estimators=1066; total time=   6.0s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=1, min_samples_split=12, n_estimators=1355; total time=   9.5s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=3, min_samples_split=12, n_estimators=488; total time=   2.8s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=4, min_samples_split=16, n_estimators=1500; total time=   9.4s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=3, min_samples_split=8, n_estimators=1211; total time=   7.4s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=4, min_samples_split=15, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=2, min_samples_split=12, n_estimators=1211; total time=   7.2s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=3, min_samples_split=15, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=2, min_samples_split=14, n_estimators=1355; total time=   9.0s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=12, n_estimators=922; total time=   6.2s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=3, min_samples_split=15, n_estimators=488; total time=   2.8s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=14, n_estimators=1211; total time=   7.9s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=4, min_samples_split=16, n_estimators=1500; total time=   9.5s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=1, min_samples_split=10, n_estimators=1355; total time=   8.2s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=1, min_samples_split=14, n_estimators=1500; total time=   8.6s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=1, min_samples_split=18, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=1, min_samples_split=10, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=4, min_samples_split=18, n_estimators=633; total time=   3.8s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=8, n_estimators=922; total time=   7.2s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=1, min_samples_split=12, n_estimators=488; total time=   3.4s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=3, min_samples_split=15, n_estimators=1355; total time=   9.4s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=2, min_samples_split=16, n_estimators=1066; total time=   5.8s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=3, min_samples_split=18, n_estimators=777; total time=   4.8s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=1, min_samples_split=16, n_estimators=633; total time=   4.1s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=3, min_samples_split=14, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   7.8s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=1, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=12, n_estimators=1355; total time=   9.1s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=2, min_samples_split=8, n_estimators=1355; total time=  10.0s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=2, min_samples_split=14, n_estimators=1500; total time=   8.4s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=3, min_samples_split=12, n_estimators=1355; total time=   9.2s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=2, min_samples_split=15, n_estimators=633; total time=   4.1s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=3, min_samples_split=15, n_estimators=1500; total time=   9.6s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=2, min_samples_split=14, n_estimators=1355; total time=   8.9s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   8.7s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=14, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=18, n_estimators=922; total time=   5.1s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=3, min_samples_split=18, n_estimators=922; total time=   5.8s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=2, min_samples_split=15, n_estimators=1066; total time=   6.9s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=1, min_samples_split=16, n_estimators=633; total time=   4.2s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=4, min_samples_split=18, n_estimators=1211; total time=   6.4s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=2, min_samples_split=16, n_estimators=922; total time=   5.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=16, n_estimators=633; total time=   3.4s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=4, min_samples_split=18, n_estimators=633; total time=   4.0s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=8, n_estimators=922; total time=   6.8s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=2, min_samples_split=10, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=18, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=1, min_samples_split=15, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=1, min_samples_split=8, n_estimators=633; total time=   4.0s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=4, min_samples_split=18, n_estimators=633; total time=   3.9s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=1, min_samples_split=18, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=1, min_samples_split=16, n_estimators=777; total time=   4.4s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=4, min_samples_split=10, n_estimators=922; total time=   5.3s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=12, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=4, min_samples_split=14, n_estimators=777; total time=   4.3s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=2, min_samples_split=15, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=1, min_samples_split=18, n_estimators=633; total time=   3.4s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=2, min_samples_split=8, n_estimators=488; total time=   3.6s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=4, min_samples_split=16, n_estimators=488; total time=   3.0s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=1, min_samples_split=15, n_estimators=1355; total time=   8.9s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=3, min_samples_split=14, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=4, min_samples_split=10, n_estimators=1066; total time=   6.1s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=2, min_samples_split=14, n_estimators=1066; total time=   7.3s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=3, min_samples_split=12, n_estimators=1355; total time=   9.1s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=3, min_samples_split=12, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=18, n_estimators=922; total time=   5.8s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=4, min_samples_split=16, n_estimators=922; total time=   4.9s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=2, min_samples_split=14, n_estimators=1355; total time=   7.6s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=12, n_estimators=1355; total time=   8.8s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=1, min_samples_split=18, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=12, n_estimators=922; total time=   6.1s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=3, min_samples_split=18, n_estimators=922; total time=   5.7s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=2, min_samples_split=15, n_estimators=1066; total time=   6.9s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=4, min_samples_split=12, n_estimators=1355; total time=   7.5s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=3, min_samples_split=16, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=2, min_samples_split=8, n_estimators=1355; total time=   8.3s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=14, n_estimators=777; total time=   5.1s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=4, min_samples_split=12, n_estimators=1500; total time=   8.5s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=1, min_samples_split=12, n_estimators=1066; total time=   6.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=14, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=3, min_samples_split=8, n_estimators=633; total time=   4.5s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=16, n_estimators=922; total time=   5.7s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=2, min_samples_split=10, n_estimators=922; total time=   5.4s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=4, min_samples_split=14, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=3, min_samples_split=16, n_estimators=922; total time=   5.0s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=10, n_estimators=488; total time=   3.4s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=1066; total time=   5.8s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=14, n_estimators=1500; total time=   8.5s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=3, min_samples_split=15, n_estimators=1355; total time=   7.4s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=1, min_samples_split=18, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=2, min_samples_split=14, n_estimators=1500; total time=   8.5s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=3, min_samples_split=12, n_estimators=1355; total time=   9.2s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=4, min_samples_split=18, n_estimators=1211; total time=   6.7s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=1, min_samples_split=8, n_estimators=922; total time=   5.9s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=2, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=4, min_samples_split=16, n_estimators=633; total time=   3.4s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=1, min_samples_split=18, n_estimators=1355; total time=   7.4s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=3, min_samples_split=12, n_estimators=1066; total time=   6.0s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=14, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=18, n_estimators=922; total time=   5.0s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=3, min_samples_split=8, n_estimators=1500; total time=   9.5s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=16, n_estimators=1211; total time=   8.0s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=12, n_estimators=633; total time=   4.3s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=3, min_samples_split=16, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   8.6s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=3, min_samples_split=10, n_estimators=1355; total time=   7.8s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=2, min_samples_split=18, n_estimators=922; total time=   5.0s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=15, n_estimators=922; total time=   5.9s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=1, min_samples_split=15, n_estimators=1355; total time=   7.6s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   8.6s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=1, min_samples_split=16, n_estimators=633; total time=   4.1s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=3, min_samples_split=14, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=14, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=2, min_samples_split=16, n_estimators=633; total time=   4.0s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=4, min_samples_split=15, n_estimators=488; total time=   3.0s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=1, min_samples_split=18, n_estimators=633; total time=   3.4s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=4, min_samples_split=8, n_estimators=1355; total time=   9.4s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=3, min_samples_split=14, n_estimators=777; total time=   5.0s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=2, min_samples_split=16, n_estimators=488; total time=   2.6s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=1, min_samples_split=15, n_estimators=633; total time=   3.7s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=1, min_samples_split=15, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=3, min_samples_split=18, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=3, min_samples_split=8, n_estimators=922; total time=   5.6s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=1, min_samples_split=16, n_estimators=633; total time=   3.3s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=1, min_samples_split=15, n_estimators=488; total time=   2.8s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=3, min_samples_split=18, n_estimators=1211; total time=   7.5s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   2.5s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=2, min_samples_split=10, n_estimators=488; total time=   2.9s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=1, min_samples_split=12, n_estimators=1500; total time=   8.6s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=3, min_samples_split=10, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=3, min_samples_split=8, n_estimators=488; total time=   2.9s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=2, min_samples_split=15, n_estimators=1500; total time=   8.3s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=3, min_samples_split=15, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=2, min_samples_split=10, n_estimators=633; total time=   3.7s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=14, n_estimators=1066; total time=   6.1s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=1, min_samples_split=18, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=3, min_samples_split=16, n_estimators=1066; total time=   5.9s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=2, min_samples_split=10, n_estimators=922; total time=   6.6s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=3, min_samples_split=18, n_estimators=488; total time=   2.8s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=1, min_samples_split=18, n_estimators=1355; total time=   8.5s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=1, min_samples_split=12, n_estimators=344; total time=   2.4s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=1, min_samples_split=18, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=2, min_samples_split=8, n_estimators=777; total time=   5.6s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=2, min_samples_split=16, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=1, min_samples_split=14, n_estimators=922; total time=   5.2s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   8.6s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=1, min_samples_split=10, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=1, min_samples_split=16, n_estimators=1500; total time=   8.3s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=2, min_samples_split=8, n_estimators=488; total time=   3.6s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=4, min_samples_split=16, n_estimators=488; total time=   3.0s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=1, min_samples_split=15, n_estimators=1355; total time=   8.8s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=3, min_samples_split=14, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=3, min_samples_split=18, n_estimators=1355; total time=   7.1s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=3, min_samples_split=15, n_estimators=1211; total time=   6.6s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   8.3s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=3, min_samples_split=14, n_estimators=1211; total time=   6.7s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=10, n_estimators=488; total time=   3.4s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=16, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=1, min_samples_split=14, n_estimators=1355; total time=   9.1s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=1, min_samples_split=15, n_estimators=922; total time=   6.1s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=3, min_samples_split=10, n_estimators=488; total time=   3.3s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=1, min_samples_split=10, n_estimators=1355; total time=   8.3s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=14, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=3, min_samples_split=10, n_estimators=488; total time=   2.9s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=2, min_samples_split=10, n_estimators=633; total time=   3.7s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=14, n_estimators=1066; total time=   5.9s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=1, min_samples_split=18, n_estimators=488; total time=   3.3s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=4, min_samples_split=16, n_estimators=922; total time=   6.5s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=1, min_samples_split=16, n_estimators=777; total time=   5.0s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=2, min_samples_split=8, n_estimators=777; total time=   5.9s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=8, n_estimators=1355; total time=  10.0s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=4, min_samples_split=8, n_estimators=344; total time=   2.4s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=1, min_samples_split=15, n_estimators=1500; total time=   9.9s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   8.6s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   8.6s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=2, min_samples_split=18, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=2, min_samples_split=16, n_estimators=633; total time=   4.1s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=1, min_samples_split=18, n_estimators=1355; total time=   8.6s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=3, min_samples_split=14, n_estimators=633; total time=   4.1s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=3, min_samples_split=8, n_estimators=1211; total time=   7.3s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=2, min_samples_split=8, n_estimators=488; total time=   3.0s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=2, min_samples_split=12, n_estimators=777; total time=   4.5s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=3, min_samples_split=12, n_estimators=777; total time=   4.4s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=4, min_samples_split=15, n_estimators=1211; total time=   7.5s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=2, min_samples_split=16, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=18, n_estimators=922; total time=   5.9s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=4, min_samples_split=16, n_estimators=922; total time=   5.1s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=2, min_samples_split=14, n_estimators=1355; total time=   7.5s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=12, n_estimators=1355; total time=   8.9s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=3, min_samples_split=8, n_estimators=488; total time=   2.9s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=2, min_samples_split=8, n_estimators=1500; total time=  11.4s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=3, min_samples_split=8, n_estimators=1211; total time=   8.6s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=2, min_samples_split=15, n_estimators=1066; total time=   5.9s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   8.6s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=1, min_samples_split=16, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=3, min_samples_split=14, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=8, n_estimators=1355; total time=  10.2s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=4, min_samples_split=8, n_estimators=344; total time=   2.4s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=1, min_samples_split=15, n_estimators=1500; total time=   9.8s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=10, n_estimators=777; total time=   5.5s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=2, min_samples_split=12, n_estimators=1211; total time=   8.4s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=18, n_estimators=1355; total time=   8.6s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=1066; total time=   6.0s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=2, min_samples_split=10, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=4, min_samples_split=12, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=2, min_samples_split=16, n_estimators=1500; total time=   9.6s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=2, min_samples_split=14, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=16, n_estimators=1066; total time=   6.8s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=3, min_samples_split=18, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=3, min_samples_split=8, n_estimators=922; total time=   5.6s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=1, min_samples_split=16, n_estimators=633; total time=   3.6s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=4, min_samples_split=8, n_estimators=1355; total time=   8.1s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=1, min_samples_split=15, n_estimators=1066; total time=   6.1s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=4, min_samples_split=14, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=3, min_samples_split=18, n_estimators=1355; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=14, n_estimators=1066; total time=   6.6s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=1, min_samples_split=18, n_estimators=922; total time=   5.2s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=3, min_samples_split=10, n_estimators=488; total time=   3.4s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=2, min_samples_split=18, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=1355; total time=   9.2s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=1, min_samples_split=16, n_estimators=633; total time=   4.2s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=12, n_estimators=633; total time=   4.3s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=1, min_samples_split=16, n_estimators=1500; total time=   9.8s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=1, min_samples_split=16, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=1, min_samples_split=10, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=2, min_samples_split=10, n_estimators=1355; total time=   8.1s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=2, min_samples_split=10, n_estimators=344; total time=   2.4s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=1, min_samples_split=12, n_estimators=1066; total time=   6.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=488; total time=   2.8s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=14, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=2, min_samples_split=8, n_estimators=1211; total time=   7.5s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=4, min_samples_split=8, n_estimators=1355; total time=   8.0s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=1, min_samples_split=12, n_estimators=1066; total time=   6.2s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=1, min_samples_split=18, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=1, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=12, n_estimators=1355; total time=   9.4s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=2, min_samples_split=8, n_estimators=1355; total time=  10.1s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=1, min_samples_split=15, n_estimators=633; total time=   3.9s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=1, min_samples_split=15, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=3, min_samples_split=18, n_estimators=1066; total time=   5.8s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=1, min_samples_split=14, n_estimators=344; total time=   2.4s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=1, min_samples_split=16, n_estimators=633; total time=   3.4s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=4, min_samples_split=18, n_estimators=1066; total time=   6.7s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=10, n_estimators=488; total time=   3.6s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=633; total time=   3.6s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=2, min_samples_split=16, n_estimators=922; total time=   5.1s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=1, min_samples_split=12, n_estimators=1500; total time=   8.9s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=3, min_samples_split=10, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=1, min_samples_split=18, n_estimators=1500; total time=   8.0s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=4, min_samples_split=16, n_estimators=1500; total time=   9.4s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=1, min_samples_split=10, n_estimators=1355; total time=   8.2s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=1, min_samples_split=14, n_estimators=1500; total time=   8.6s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=1, min_samples_split=18, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=1, min_samples_split=10, n_estimators=488; total time=   3.4s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=2, min_samples_split=16, n_estimators=1211; total time=   7.8s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=3, min_samples_split=18, n_estimators=1066; total time=   5.7s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=12, n_estimators=1211; total time=   8.4s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=2, min_samples_split=16, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=1, min_samples_split=14, n_estimators=922; total time=   5.3s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   9.1s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=4, min_samples_split=14, n_estimators=777; total time=   4.5s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=4, min_samples_split=18, n_estimators=777; total time=   4.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=14, n_estimators=922; total time=   5.7s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=  10.6s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=1, min_samples_split=8, n_estimators=777; total time=   5.9s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=3, min_samples_split=8, n_estimators=633; total time=   3.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=12, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=1, min_samples_split=12, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=4, min_samples_split=10, n_estimators=1500; total time=   8.7s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=1, min_samples_split=12, n_estimators=633; total time=   3.7s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=2, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=2, min_samples_split=8, n_estimators=1500; total time=  11.0s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=3, min_samples_split=15, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=4, min_samples_split=18, n_estimators=1066; total time=   6.5s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=4, min_samples_split=18, n_estimators=1066; total time=   5.6s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=4, min_samples_split=18, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=3, min_samples_split=14, n_estimators=922; total time=   5.1s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=2, min_samples_split=14, n_estimators=1355; total time=   8.8s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=1, min_samples_split=8, n_estimators=922; total time=   7.0s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=1, min_samples_split=16, n_estimators=1211; total time=   6.7s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=15, n_estimators=777; total time=   4.3s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=1, min_samples_split=14, n_estimators=488; total time=   2.8s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=3, min_samples_split=18, n_estimators=488; total time=   2.6s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=1, min_samples_split=15, n_estimators=1211; total time=   8.2s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=1, min_samples_split=8, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=4, min_samples_split=16, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=14, n_estimators=1500; total time=   9.4s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   2.7s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=3, min_samples_split=15, n_estimators=777; total time=   5.0s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=16, n_estimators=1355; total time=   8.5s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=2, min_samples_split=15, n_estimators=633; total time=   3.8s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=1, min_samples_split=8, n_estimators=1500; total time=  11.5s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=3, min_samples_split=14, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=1, min_samples_split=8, n_estimators=1500; total time=  12.1s
# ...
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   8.6s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=14, n_estimators=1500; total time=   8.9s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=4, min_samples_split=15, n_estimators=777; total time=   5.0s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=8, n_estimators=1211; total time=   8.6s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=3, min_samples_split=18, n_estimators=777; total time=   4.9s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=3, min_samples_split=10, n_estimators=344; total time=   2.6s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=   9.3s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=1, min_samples_split=15, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=1, min_samples_split=14, n_estimators=1355; total time=   7.8s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=3, min_samples_split=15, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=8, n_estimators=344; total time=   2.5s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=2, min_samples_split=10, n_estimators=488; total time=   2.9s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=1, min_samples_split=10, n_estimators=922; total time=   6.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=4, min_samples_split=14, n_estimators=1066; total time=   6.6s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=3, min_samples_split=14, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=4, min_samples_split=14, n_estimators=1211; total time=   6.8s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=4, min_samples_split=16, n_estimators=1500; total time=   8.1s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=4, min_samples_split=15, n_estimators=777; total time=   4.9s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=2, min_samples_split=15, n_estimators=1211; total time=   6.8s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=2, min_samples_split=16, n_estimators=922; total time=   5.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=16, n_estimators=633; total time=   3.7s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=3, min_samples_split=14, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=14, n_estimators=777; total time=   4.4s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=4, min_samples_split=14, n_estimators=777; total time=   4.3s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=1, min_samples_split=8, n_estimators=1211; total time=   9.2s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=18, n_estimators=1355; total time=   8.4s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=4, min_samples_split=16, n_estimators=922; total time=   5.0s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   8.6s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=1, min_samples_split=10, n_estimators=1500; total time=  10.9s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=4, min_samples_split=14, n_estimators=1500; total time=   8.3s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=8, n_estimators=1355; total time=  10.8s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=3, min_samples_split=8, n_estimators=488; total time=   3.6s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=4, min_samples_split=8, n_estimators=1500; total time=   9.0s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=3, min_samples_split=18, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=1, min_samples_split=10, n_estimators=1211; total time=   6.9s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=2, min_samples_split=16, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=3, min_samples_split=15, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=4, min_samples_split=12, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=4, min_samples_split=18, n_estimators=1355; total time=   8.3s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=4, min_samples_split=16, n_estimators=922; total time=   5.7s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=12, n_estimators=922; total time=   6.1s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=3, min_samples_split=15, n_estimators=488; total time=   2.6s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=3, min_samples_split=16, n_estimators=344; total time=   1.8s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=4, min_samples_split=16, n_estimators=633; total time=   3.8s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=4, min_samples_split=16, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=1, min_samples_split=12, n_estimators=1500; total time=  10.7s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=16, n_estimators=344; total time=   1.9s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=2, min_samples_split=18, n_estimators=777; total time=   4.2s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=3, min_samples_split=10, n_estimators=1066; total time=   7.4s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=4, min_samples_split=16, n_estimators=1066; total time=   6.6s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=1, min_samples_split=10, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=2, min_samples_split=10, n_estimators=1355; total time=   8.0s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=1, min_samples_split=8, n_estimators=488; total time=   3.7s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=18, n_estimators=777; total time=   4.7s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=1, min_samples_split=10, n_estimators=633; total time=   3.8s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=4, min_samples_split=18, n_estimators=777; total time=   4.7s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=4, min_samples_split=14, n_estimators=1500; total time=   8.2s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=15, n_estimators=488; total time=   3.1s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=4, min_samples_split=14, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=3, min_samples_split=16, n_estimators=922; total time=   5.0s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=3, min_samples_split=18, n_estimators=633; total time=   3.4s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=1066; total time=   6.0s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=2, min_samples_split=10, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=2, min_samples_split=14, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=4, min_samples_split=8, n_estimators=1355; total time=   8.1s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=10, n_estimators=1500; total time=  10.7s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=3, min_samples_split=14, n_estimators=1211; total time=   7.0s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=2, min_samples_split=14, n_estimators=633; total time=   3.6s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=2, min_samples_split=14, n_estimators=1500; total time=   5.7s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=4, min_samples_split=8, n_estimators=1355; total time=   8.2s
# [CV] END bootstrap=True, max_depth=52, min_samples_leaf=4, min_samples_split=16, n_estimators=922; total time=   5.0s
# [CV] END bootstrap=True, max_depth=74, min_samples_leaf=2, min_samples_split=14, n_estimators=1355; total time=   8.0s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=1, min_samples_split=15, n_estimators=922; total time=   6.0s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=3, min_samples_split=10, n_estimators=488; total time=   3.4s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=4, min_samples_split=18, n_estimators=344; total time=   2.1s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=4, min_samples_split=14, n_estimators=1211; total time=   6.8s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=3, min_samples_split=14, n_estimators=1355; total time=   8.8s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=4, min_samples_split=12, n_estimators=1355; total time=   7.7s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=1, min_samples_split=16, n_estimators=1500; total time=   9.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=88, min_samples_leaf=3, min_samples_split=10, n_estimators=1355; total time=   7.9s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=4, min_samples_split=14, n_estimators=777; total time=   4.3s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=1, min_samples_split=8, n_estimators=1211; total time=   9.2s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=4, min_samples_split=18, n_estimators=633; total time=   3.9s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=1, min_samples_split=18, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=1, min_samples_split=16, n_estimators=777; total time=   4.3s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=4, min_samples_split=10, n_estimators=922; total time=   5.3s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=12, n_estimators=200; total time=   1.1s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=1, min_samples_split=16, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=4, min_samples_split=14, n_estimators=777; total time=   4.3s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=2, min_samples_split=15, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=1, min_samples_split=18, n_estimators=633; total time=   3.5s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=12, n_estimators=1066; total time=   7.3s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=4, min_samples_split=12, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=1, min_samples_split=14, n_estimators=777; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=18, n_estimators=922; total time=   5.0s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=2, min_samples_split=10, n_estimators=1355; total time=   9.7s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=3, min_samples_split=10, n_estimators=1500; total time=   9.0s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=2, min_samples_split=14, n_estimators=1500; total time=   6.0s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=4, min_samples_split=14, n_estimators=344; total time=   2.2s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=3, min_samples_split=15, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=4, min_samples_split=12, n_estimators=633; total time=   3.6s
# [CV] END bootstrap=False, max_depth=110, min_samples_leaf=4, min_samples_split=18, n_estimators=1355; total time=   8.3s
# [CV] END bootstrap=False, max_depth=88, min_samples_leaf=4, min_samples_split=16, n_estimators=922; total time=   5.8s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=4, min_samples_split=14, n_estimators=1355; total time=   8.7s
# [CV] END bootstrap=False, max_depth=52, min_samples_leaf=2, min_samples_split=14, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=18, n_estimators=922; total time=   5.0s
# [CV] END bootstrap=True, max_depth=38, min_samples_leaf=3, min_samples_split=12, n_estimators=488; total time=   2.8s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=1, min_samples_split=18, n_estimators=922; total time=   5.1s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=4, min_samples_split=12, n_estimators=344; total time=   2.3s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=3, min_samples_split=16, n_estimators=1211; total time=   7.7s
# [CV] END bootstrap=True, max_depth=60, min_samples_leaf=2, min_samples_split=12, n_estimators=1211; total time=   7.1s
# [CV] END bootstrap=False, max_depth=102, min_samples_leaf=1, min_samples_split=16, n_estimators=777; total time=   5.3s
# [CV] END bootstrap=False, max_depth=74, min_samples_leaf=2, min_samples_split=8, n_estimators=777; total time=   5.7s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=14, n_estimators=777; total time=   4.7s
# [CV] END bootstrap=True, max_depth=110, min_samples_leaf=2, min_samples_split=14, n_estimators=488; total time=   2.7s
# [CV] END bootstrap=False, max_depth=67, min_samples_leaf=2, min_samples_split=14, n_estimators=1500; total time=   9.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=14, n_estimators=344; total time=   2.0s
# [CV] END bootstrap=False, max_depth=31, min_samples_leaf=3, min_samples_split=18, n_estimators=922; total time=   5.7s
# [CV] END bootstrap=False, max_depth=81, min_samples_leaf=2, min_samples_split=14, n_estimators=633; total time=   4.2s
# [CV] END bootstrap=True, max_depth=67, min_samples_leaf=4, min_samples_split=8, n_estimators=1355; total time=   8.9s
# [CV] END bootstrap=True, max_depth=81, min_samples_leaf=1, min_samples_split=16, n_estimators=1500; total time=   8.6s
# [CV] END bootstrap=False, max_depth=95, min_samples_leaf=2, min_samples_split=12, n_estimators=1066; total time=   8.0s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=2, min_samples_split=14, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=False, max_depth=60, min_samples_leaf=1, min_samples_split=14, n_estimators=777; total time=   5.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=18, n_estimators=922; total time=   4.8s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=2, min_samples_split=10, n_estimators=1355; total time=   9.5s
# [CV] END bootstrap=True, max_depth=95, min_samples_leaf=3, min_samples_split=10, n_estimators=1500; total time=   9.0s
# [CV] END bootstrap=True, max_depth=102, min_samples_leaf=2, min_samples_split=14, n_estimators=1500; total time=   5.8s

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Permutation Test
#
#
# Reference:
#
# [1]
# Ojala and Garriga. Permutation Tests for Studying Classifier Performance. The Journal of Machine Learning Research (2010) vol. 11

# %%
## Permutation Test

rf_tuned = joblib.load(open('models/nb_downsampled_trn_set.joblib', 'rb'))

rng = np.random.RandomState(seed=0)
# Use same number of samples and features as in the original data 
X_rand = np.random.permutation(X_train_encoded)

clf = rf_tuned
cv = StratifiedKFold(2, shuffle=True, random_state=1)

score_data, perm_scores_data, pvalue_data = permutation_test_score(
    clf, X_train_encoded, y_train_encoded, scoring="balanced_accuracy", cv=cv, n_permutations=1000
)

score_rand, perm_scores_rand, pvalue_rand = permutation_test_score(
    clf, X_rand, y_train_encoded, scoring="balanced_accuracy", cv=cv, n_permutations=1000
)
plt.figure(figsize=(7,5))
sns.set_style("white")

g = sns.histplot(perm_scores_data, binwidth=0.009, common_norm=True, label='scores on permuted data')
plt.vlines(score_data, ymin=0, ymax=51, ls="--", color="r", label='score on original data')

g.legend(title=f'p-value: {pvalue_data:.2f}',frameon=False)
g.set_xlim(0,1)
g.set_xlabel('balanced accuracy score')
g.set_xticks([0, perm_scores_data.mean(), score_data.round(2), 0.5, 0.75, 1])
g.set_xticklabels([0, perm_scores_data.mean().round(2), score_data.round(2), 0.5, 0.75, 1])
sns.despine()

plt.figure(figsize=(7,5))
sns.set_style("white")
sns.set_style("ticks")

g = sns.histplot(perm_scores_rand, binwidth=0.009, common_norm=True, label='scores on permuted data')
plt.vlines(score_rand, ymin=0, ymax=51, ls="--", color="r", label='score on random data')

g.legend(title=f'p-value: {pvalue_rand:.2f}',frameon=False)
g.set_xlim(0,1)
g.set_xlabel('balanced accuracy score')
g.set_xticks([0, perm_scores_rand.mean(), score_rand.round(2), 0.5, 0.75, 1])
g.set_xticklabels([0, perm_scores_rand.mean().round(2), score_rand.round(2), 0.5, 0.75, 1])
sns.despine()
# Out:
# /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/base.py:288: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.1.3 when using version 1.2.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/base.py:288: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.1.3 when using version 1.2.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 13
#      10 clf = rf_tuned
#      11 cv = StratifiedKFold(2, shuffle=True, random_state=1)
# ---> 13 score_data, perm_scores_data, pvalue_data = permutation_test_score(
#      14     clf, X_train_encoded, y_train_encoded, scoring="balanced_accuracy", cv=cv, n_permutations=1000
#      15 )
#      17 score_rand, perm_scores_rand, pvalue_rand = permutation_test_score(
#      18     clf, X_rand, y_train_encoded, scoring="balanced_accuracy", cv=cv, n_permutations=1000
#      19 )
#      20 plt.figure(figsize=(7,5))
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:1307, in permutation_test_score(estimator, X, y, groups, cv, n_permutations, n_jobs, random_state, verbose, scoring, fit_params)
#    1302 # We clone the estimator to make sure that all the folds are
#    1303 # independent, and that it is pickle-able.
#    1304 score = _permutation_test_score(
#    1305     clone(estimator), X, y, groups, cv, scorer, fit_params=fit_params
#    1306 )
# -> 1307 permutation_scores = Parallel(n_jobs=n_jobs, verbose=verbose)(
#    1308     delayed(_permutation_test_score)(
#    1309         clone(estimator),
#    1310         X,
#    1311         _shuffle(y, groups, random_state),
#    1312         groups,
#    1313         cv,
#    1314         scorer,
#    1315         fit_params=fit_params,
#    1316     )
#    1317     for _ in range(n_permutations)
#    1318 )
#    1319 permutation_scores = np.array(permutation_scores)
#    1320 pvalue = (np.sum(permutation_scores >= score) + 1.0) / (n_permutations + 1)
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:1333, in _permutation_test_score(estimator, X, y, groups, cv, scorer, fit_params)
#    1331     X_test, y_test = _safe_split(estimator, X, y, test, train)
#    1332     fit_params = _check_fit_params(X, fit_params, train)
# -> 1333     estimator.fit(X_train, y_train, **fit_params)
#    1334     avg_score.append(scorer(estimator, X_test, y_test))
#    1335 return np.mean(avg_score)
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:463, in BaseForest.fit(self, X, y, sample_weight)
#     458 if self.warm_start and len(self.estimators_) > 0:
#     459     # We draw from the random state to get the random state we
#     460     # would have got if we hadn't used a warm_start.
#     461     random_state.randint(MAX_INT, size=len(self.estimators_))
# --> 463 trees = [
#     464     self._make_estimator(append=False, random_state=random_state)
#     465     for i in range(n_more_estimators)
#     466 ]
#     468 # Parallel loop: we prefer the threading backend as the Cython code
#     469 # for fitting the trees is internally releasing the Python GIL
#     470 # making threading more efficient than multiprocessing in
#     471 # that case. However, for joblib 0.12+ we respect any
#     472 # parallel_backend contexts set at a higher level,
#     473 # since correctness does not rely on using threads.
#     474 trees = Parallel(
#     475     n_jobs=self.n_jobs,
#     476     verbose=self.verbose,
#    (...)
#     491     for i, t in enumerate(trees)
#     492 )
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:464, in <listcomp>(.0)
#     458 if self.warm_start and len(self.estimators_) > 0:
#     459     # We draw from the random state to get the random state we
#     460     # would have got if we hadn't used a warm_start.
#     461     random_state.randint(MAX_INT, size=len(self.estimators_))
#     463 trees = [
# --> 464     self._make_estimator(append=False, random_state=random_state)
#     465     for i in range(n_more_estimators)
#     466 ]
#     468 # Parallel loop: we prefer the threading backend as the Cython code
#     469 # for fitting the trees is internally releasing the Python GIL
#     470 # making threading more efficient than multiprocessing in
#     471 # that case. However, for joblib 0.12+ we respect any
#     472 # parallel_backend contexts set at a higher level,
#     473 # since correctness does not rely on using threads.
#     474 trees = Parallel(
#     475     n_jobs=self.n_jobs,
#     476     verbose=self.verbose,
#    (...)
#     491     for i, t in enumerate(trees)
#     492 )
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/ensemble/_base.py:198, in BaseEnsemble._make_estimator(self, append, random_state)
#     192 def _make_estimator(self, append=True, random_state=None):
#     193     """Make and configure a copy of the `estimator_` attribute.
#     194
#     195     Warning: This method should be used to properly instantiate new
#     196     sub-estimators.
#     197     """
# --> 198     estimator = clone(self.estimator_)
#     199     estimator.set_params(**{p: getattr(self, p) for p in self.estimator_params})
#     201     # TODO(1.3): Remove
#     202     # max_features = 'auto' would cause warnings in every call to
#     203     # Tree.fit(..)
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/base.py:90, in clone(estimator, safe)
#      88 for name, param in new_object_params.items():
#      89     new_object_params[name] = clone(param, safe=False)
# ---> 90 new_object = klass(**new_object_params)
#      91 params_set = new_object.get_params(deep=False)
#      93 # quick sanity check of the parameters of the clone
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/tree/_classes.py:844, in DecisionTreeClassifier.__init__(self, criterion, splitter, max_depth, min_samples_split, min_samples_leaf, min_weight_fraction_leaf, max_features, random_state, max_leaf_nodes, min_impurity_decrease, class_weight, ccp_alpha)
#     828 def __init__(
#     829     self,
#     830     *,
#    (...)
#     842     ccp_alpha=0.0,
#     843 ):
# --> 844     super().__init__(
#     845         criterion=criterion,
#     846         splitter=splitter,
#     847         max_depth=max_depth,
#     848         min_samples_split=min_samples_split,
#     849         min_samples_leaf=min_samples_leaf,
#     850         min_weight_fraction_leaf=min_weight_fraction_leaf,
#     851         max_features=max_features,
#     852         max_leaf_nodes=max_leaf_nodes,
#     853         class_weight=class_weight,
#     854         random_state=random_state,
#     855         min_impurity_decrease=min_impurity_decrease,
#     856         ccp_alpha=ccp_alpha,
#     857     )
#
# File /usr/local/anaconda3/envs/dating/lib/python3.9/site-packages/sklearn/tree/_classes.py:138, in BaseDecisionTree.__init__(self, criterion, splitter, max_depth, min_samples_split, min_samples_leaf, min_weight_fraction_leaf, max_features, max_leaf_nodes, random_state, min_impurity_decrease, class_weight, ccp_alpha)
#     121 @abstractmethod
#     122 def __init__(
#     123     self,
#    (...)
#     136     ccp_alpha=0.0,
#     137 ):
# --> 138     self.criterion = criterion
#     139     self.splitter = splitter
#     140     self.max_depth = max_depth
#
# KeyboardInterrupt:
